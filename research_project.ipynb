# %%
# imports
import pandas as pd
import os
import numpy as np
from IPython.display import display

# %%
pip install ace_tools
# Out:
# Collecting ace_tools
#   Downloading ace_tools-0.0-py3-none-any.whl.metadata (300 bytes)
# Downloading ace_tools-0.0-py3-none-any.whl (1.1 kB)
# Installing collected packages: ace_tools
# Successfully installed ace_tools-0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pd.set_option('display.max_columns',None)

# %%
current_path = os.getcwd()
print(fr'{current_path}')
# Out:
# C:\Users\utsav\Desktop\personal\research

# %%
# filename initials
demography = "DEMO"
outcome = "OUTC"
reaction = "REAC"
indication = "INDI"
report_src = "RPSR"
therapy ='THER'
drug = 'DRUG'

# %%
data_q24 = r'data\\faers_ascii_2024Q4'
directory_path = os.path.join(current_path, data_q24)
antihistamines = ["Fexofenadine", "Cetirizine", "Loratadine", "Levocetirizine"]

# %%
def read_faers_file(file_name, delimiter="$"):
  file_path = os.path.join(directory_path, file_name)
  df = pd.read_csv(file_path, sep=delimiter, dtype=str)
  df['caseid'] = pd.to_numeric(df['caseid'], errors='coerce')
  return df

# %%
def explore_missing_vals(df, file_name):
  print(f'Missing values for {file_name}: ')
  print(df.isnull().sum())

# %%
# searching in the drug dataset where antihistamines are the primary suspect
def filter_antihistamines(drug_df):
  return drug_df[(drug_df["drugname"].str.contains('|'.join(antihistamines), case=False, na=False))
                 & (drug_df["role_cod"] == "PS")]

# %%
def dataset_summary(df, column, top_n=10):
    print(f"\nTop {top_n} {column} in dataset:")
    print(df[column].value_counts().head(top_n))

# %%
def merge_faers_data(filtered_drug_df, reac_df, demo_df, outc_df,rpsr_df):
    merged_df = (
        filtered_drug_df
        .merge(reac_df, on="caseid", how="left",suffixes=('', '_reac'))
        .merge(demo_df, on="caseid", how="left", suffixes=('', '_demo'))
        .merge(outc_df, on="caseid", how="left", suffixes=('', '_outc'))
        .merge(rpsr_df, on="caseid", how="left",suffixes=('', '_rpsr'))
    )
    return merged_df

# %%
def count_reactions_by_source(merged_df):
    source_counts = merged_df.groupby("rpsr_cod")["caseid"].count().reset_index()
    source_counts.columns = ["report_source", "reaction_count"]
    return source_counts

# %%
#processing the data
def process_faers_dataset():
    drug_df = read_faers_file(f'{drug}24Q4.txt')
    reac_df = read_faers_file(f"{reaction}24Q4.txt")
    demo_df = read_faers_file(f"{demography}24Q4.txt")
    outc_df = read_faers_file(f"{outcome}24Q4.txt")
    rpsr_df = read_faers_file(f"{report_src}24Q4.txt")

    filtered_drugs = filter_antihistamines(drug_df)
    final_df = merge_faers_data(filtered_drugs, reac_df, demo_df, outc_df, rpsr_df)
  # print(final_df.columns)
  # print(final_df["RPSR_COD".lower()].unique())
  # reaction_counts = count_reactions_by_source(final_df)
  # print(reaction_counts)
    return final_df

# %%
data_f = process_faers_dataset()

# %%
data_f.columns
# Out:
# Index(['primaryid', 'caseid', 'drug_seq', 'role_cod', 'drugname', 'prod_ai',
#        'val_vbm', 'route', 'dose_vbm', 'cum_dose_chr', 'cum_dose_unit',
#        'dechal', 'rechal', 'lot_num', 'exp_dt', 'nda_num', 'dose_amt',
#        'dose_unit', 'dose_form', 'dose_freq', 'primaryid_reac', 'pt',
#        'drug_rec_act', 'primaryid_demo', 'caseversion', 'i_f_code', 'event_dt',
#        'mfr_dt', 'init_fda_dt', 'fda_dt', 'rept_cod', 'auth_num', 'mfr_num',
#        'mfr_sndr', 'lit_ref', 'age', 'age_cod', 'age_grp', 'sex', 'e_sub',
#        'wt', 'wt_cod', 'rept_dt', 'to_mfr', 'occp_cod', 'reporter_country',
#        'occr_country', 'primaryid_outc', 'outc_cod', 'primaryid_rpsr',
#        'rpsr_cod'],
#       dtype='object')

# %%
data_f[["rept_dt","event_dt"]].head(5)
# Out:
#     rept_dt  event_dt
# 0  20241004  20110101
# 1  20241004  20110101
# 2  20241004  20110101
# 3  20241004  20110101
# 4  20241004  20110101

# %%
data_f[data_f['drugname']=='CETIRIZINE'].head(10)
# Out:
#     primaryid    caseid drug_seq role_cod    drugname  \
# 0  1454484512  14544845        3       PS  CETIRIZINE
# 1  1454484512  14544845        3       PS  CETIRIZINE
# 2  1454484512  14544845        3       PS  CETIRIZINE
# 3  1454484512  14544845        3       PS  CETIRIZINE
# 4  1454484512  14544845        3       PS  CETIRIZINE
# 5  1454484512  14544845        3       PS  CETIRIZINE
# 6  1454484512  14544845        3       PS  CETIRIZINE
# 7  1454484512  14544845        3       PS  CETIRIZINE
# 8  1454484512  14544845        3       PS  CETIRIZINE
# 9  1454484512  14544845        3       PS  CETIRIZINE
#
#                     prod_ai val_vbm    route dose_vbm cum_dose_chr  \
# 0  CETIRIZINE HYDROCHLORIDE       1  Unknown      UNK          NaN
# 1  CETIRIZINE HYDROCHLORIDE       1  Unknown      UNK          NaN
# 2  CETIRIZINE HYDROCHLORIDE       1  Unknown      UNK          NaN
# 3  CETIRIZINE HYDROCHLORIDE       1  Unknown      UNK          NaN
# 4  CETIRIZINE HYDROCHLORIDE       1  Unknown      UNK          NaN
# 5  CETIRIZINE HYDROCHLORIDE       1  Unknown      UNK          NaN
# 6  CETIRIZINE HYDROCHLORIDE       1  Unknown      UNK          NaN
# 7  CETIRIZINE HYDROCHLORIDE       1  Unknown      UNK          NaN
# 8  CETIRIZINE HYDROCHLORIDE       1  Unknown      UNK          NaN
# 9  CETIRIZINE HYDROCHLORIDE       1  Unknown      UNK          NaN
#
#   cum_dose_unit dechal rechal lot_num exp_dt nda_num dose_amt dose_unit  \
# 0           NaN      D    NaN     NaN    NaN  090750      NaN       NaN
# 1           NaN      D    NaN     NaN    NaN  090750      NaN       NaN
# 2           NaN      D    NaN     NaN    NaN  090750      NaN       NaN
# 3           NaN      D    NaN     NaN    NaN  090750      NaN       NaN
# 4           NaN      D    NaN     NaN    NaN  090750      NaN       NaN
# 5           NaN      D    NaN     NaN    NaN  090750      NaN       NaN
# 6           NaN      D    NaN     NaN    NaN  090750      NaN       NaN
# 7           NaN      D    NaN     NaN    NaN  090750      NaN       NaN
# 8           NaN      D    NaN     NaN    NaN  090750      NaN       NaN
# 9           NaN      D    NaN     NaN    NaN  090750      NaN       NaN
#
#             dose_form dose_freq primaryid_reac                pt drug_rec_act  \
# 0  Film-coated tablet       NaN     1454484512   Suicide attempt          NaN
# 1  Film-coated tablet       NaN     1454484512   Suicide attempt          NaN
# 2  Film-coated tablet       NaN     1454484512   Suicide attempt          NaN
# 3  Film-coated tablet       NaN     1454484512  Hepatic necrosis          NaN
# 4  Film-coated tablet       NaN     1454484512  Hepatic necrosis          NaN
# 5  Film-coated tablet       NaN     1454484512  Hepatic necrosis          NaN
# 6  Film-coated tablet       NaN     1454484512     Off label use          NaN
# 7  Film-coated tablet       NaN     1454484512     Off label use          NaN
# 8  Film-coated tablet       NaN     1454484512     Off label use          NaN
# 9  Film-coated tablet       NaN     1454484512        Drug abuse          NaN
#
#   primaryid_demo caseversion i_f_code  event_dt    mfr_dt init_fda_dt  \
# 0     1454484512          12        F  20110101  20240923    20180217
# 1     1454484512          12        F  20110101  20240923    20180217
# 2     1454484512          12        F  20110101  20240923    20180217
# 3     1454484512          12        F  20110101  20240923    20180217
# 4     1454484512          12        F  20110101  20240923    20180217
# 5     1454484512          12        F  20110101  20240923    20180217
# 6     1454484512          12        F  20110101  20240923    20180217
# 7     1454484512          12        F  20110101  20240923    20180217
# 8     1454484512          12        F  20110101  20240923    20180217
# 9     1454484512          12        F  20110101  20240923    20180217
#
#      fda_dt rept_cod auth_num                           mfr_num   mfr_sndr  \
# 0  20241004      EXP      NaN  FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 1  20241004      EXP      NaN  FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 2  20241004      EXP      NaN  FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 3  20241004      EXP      NaN  FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 4  20241004      EXP      NaN  FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 5  20241004      EXP      NaN  FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 6  20241004      EXP      NaN  FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 7  20241004      EXP      NaN  FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 8  20241004      EXP      NaN  FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 9  20241004      EXP      NaN  FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
#
#                                              lit_ref age age_cod age_grp sex  \
# 0  M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31      YR     NaN   F
# 1  M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31      YR     NaN   F
# 2  M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31      YR     NaN   F
# 3  M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31      YR     NaN   F
# 4  M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31      YR     NaN   F
# 5  M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31      YR     NaN   F
# 6  M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31      YR     NaN   F
# 7  M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31      YR     NaN   F
# 8  M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31      YR     NaN   F
# 9  M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31      YR     NaN   F
#
#   e_sub   wt wt_cod   rept_dt to_mfr occp_cod reporter_country occr_country  \
# 0     Y  NaN    NaN  20241004    NaN       MD               FR           FR
# 1     Y  NaN    NaN  20241004    NaN       MD               FR           FR
# 2     Y  NaN    NaN  20241004    NaN       MD               FR           FR
# 3     Y  NaN    NaN  20241004    NaN       MD               FR           FR
# 4     Y  NaN    NaN  20241004    NaN       MD               FR           FR
# 5     Y  NaN    NaN  20241004    NaN       MD               FR           FR
# 6     Y  NaN    NaN  20241004    NaN       MD               FR           FR
# 7     Y  NaN    NaN  20241004    NaN       MD               FR           FR
# 8     Y  NaN    NaN  20241004    NaN       MD               FR           FR
# 9     Y  NaN    NaN  20241004    NaN       MD               FR           FR
#
#   primaryid_outc outc_cod primaryid_rpsr rpsr_cod
# 0     1454484512       OT            NaN      NaN
# 1     1454484512       HO            NaN      NaN
# 2     1454484512       LT            NaN      NaN
# 3     1454484512       OT            NaN      NaN
# 4     1454484512       HO            NaN      NaN
# 5     1454484512       LT            NaN      NaN
# 6     1454484512       OT            NaN      NaN
# 7     1454484512       HO            NaN      NaN
# 8     1454484512       LT            NaN      NaN
# 9     1454484512       OT            NaN      NaN

# %%
data_f[data_f['drugname']=='CETIRIZINE'][['primaryid','caseid','drugname','pt','event_dt','outc_cod']].head(5)
# Out:
#     primaryid    caseid    drugname                pt  event_dt outc_cod
# 0  1454484512  14544845  CETIRIZINE   Suicide attempt  20110101       OT
# 1  1454484512  14544845  CETIRIZINE   Suicide attempt  20110101       HO
# 2  1454484512  14544845  CETIRIZINE   Suicide attempt  20110101       LT
# 3  1454484512  14544845  CETIRIZINE  Hepatic necrosis  20110101       OT
# 4  1454484512  14544845  CETIRIZINE  Hepatic necrosis  20110101       HO

# %%
# merging based on primaryid, caseid, drugname, event_dt and pt since multiple rows being generated for different outc_cod column
group_cols = ['primaryid', 'caseid', 'drugname', 'event_dt', 'pt']

merged_df = data_f.groupby(group_cols, as_index=False).agg({
    'outc_cod': lambda x: ','.join(x.dropna().astype(str)),  # Merge outcome codes
    **{col: lambda x: ','.join(x.astype(str).unique()) for col in data_f.columns if col not in group_cols + ['outc_cod']}
})

# %%
import subprocess

# %%
import glob
import shutil
current_dir = os.path.join(os.getcwd(),'pre-\\')
print(current_dir)
os.listdir(current_dir)
req_folder = ["ASCII",'ascii']
for folder in os.listdir(current_dir):
    path_to_work = os.path.join(current_dir, folder)
    i = folder
    # loc1 = f'"C:\\Users\\utsav\\Desktop\\personal\\research\\pre-\\{folder}\\ASCII\\*.txt"'
    # print(loc1)
    cmd = f'xcopy "C:\\Users\\utsav\\Desktop\\personal\\research\\pre-\\{folder}\\ascii\\*.txt" "C:\\Users\\utsav\\Desktop\\personal\\research\\pre-\\{folder}"'
    cmd2 = f'C:/Users/utsav/Desktop/personal/research/pre-/{folder}/ascii'
    cmd3 = fr'C:/Users/utsav/Desktop/personal/research/pre-/{folder}/deleted'
    folder_path = f"C:/Users/utsav/Desktop/personal/research/pre-/{folder}"
    for file in glob.glob(f"{folder_path}/*.pdf"):
        os.remove(file)
    for i in os.listdir(path_to_work):
        if i in req_folder:
            subprocess.run(cmd)
            # subprocess.run(cmd2)
            # subprocess.run(cmd3)
            shutil.rmtree(cmd2) 
            shutil.rmtree(cmd3)
# Out:
# C:\Users\utsav\Desktop\personal\research\pre-\

# %%
merged_df.head(5)
# Out:
#     primaryid    caseid    drugname  event_dt                         pt  \
# 0  1454484512  14544845  CETIRIZINE  20110101                 Drug abuse
# 1  1454484512  14544845  CETIRIZINE  20110101  Drug-induced liver injury
# 2  1454484512  14544845  CETIRIZINE  20110101           Hepatic necrosis
# 3  1454484512  14544845  CETIRIZINE  20110101       Intentional overdose
# 4  1454484512  14544845  CETIRIZINE  20110101              Off label use
#
#    outc_cod drug_seq role_cod                   prod_ai val_vbm    route  \
# 0  OT,HO,LT        3       PS  CETIRIZINE HYDROCHLORIDE       1  Unknown
# 1  OT,HO,LT        3       PS  CETIRIZINE HYDROCHLORIDE       1  Unknown
# 2  OT,HO,LT        3       PS  CETIRIZINE HYDROCHLORIDE       1  Unknown
# 3  OT,HO,LT        3       PS  CETIRIZINE HYDROCHLORIDE       1  Unknown
# 4  OT,HO,LT        3       PS  CETIRIZINE HYDROCHLORIDE       1  Unknown
#
#   dose_vbm cum_dose_chr cum_dose_unit dechal rechal lot_num exp_dt nda_num  \
# 0      UNK          nan           nan      D    nan     nan    nan  090750
# 1      UNK          nan           nan      D    nan     nan    nan  090750
# 2      UNK          nan           nan      D    nan     nan    nan  090750
# 3      UNK          nan           nan      D    nan     nan    nan  090750
# 4      UNK          nan           nan      D    nan     nan    nan  090750
#
#   dose_amt dose_unit           dose_form dose_freq primaryid_reac  \
# 0      nan       nan  Film-coated tablet       nan     1454484512
# 1      nan       nan  Film-coated tablet       nan     1454484512
# 2      nan       nan  Film-coated tablet       nan     1454484512
# 3      nan       nan  Film-coated tablet       nan     1454484512
# 4      nan       nan  Film-coated tablet       nan     1454484512
#
#   drug_rec_act primaryid_demo caseversion i_f_code    mfr_dt init_fda_dt  \
# 0          nan     1454484512          12        F  20240923    20180217
# 1          nan     1454484512          12        F  20240923    20180217
# 2          nan     1454484512          12        F  20240923    20180217
# 3          nan     1454484512          12        F  20240923    20180217
# 4          nan     1454484512          12        F  20240923    20180217
#
#      fda_dt rept_cod auth_num                           mfr_num   mfr_sndr  \
# 0  20241004      EXP      nan  FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 1  20241004      EXP      nan  FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 2  20241004      EXP      nan  FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 3  20241004      EXP      nan  FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 4  20241004      EXP      nan  FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
#
#                                              lit_ref age age_cod age_grp sex  \
# 0  M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31      YR     nan   F
# 1  M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31      YR     nan   F
# 2  M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31      YR     nan   F
# 3  M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31      YR     nan   F
# 4  M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31      YR     nan   F
#
#   e_sub   wt wt_cod   rept_dt to_mfr occp_cod reporter_country occr_country  \
# 0     Y  nan    nan  20241004    nan       MD               FR           FR
# 1     Y  nan    nan  20241004    nan       MD               FR           FR
# 2     Y  nan    nan  20241004    nan       MD               FR           FR
# 3     Y  nan    nan  20241004    nan       MD               FR           FR
# 4     Y  nan    nan  20241004    nan       MD               FR           FR
#
#   primaryid_outc primaryid_rpsr rpsr_cod
# 0     1454484512            nan      nan
# 1     1454484512            nan      nan
# 2     1454484512            nan      nan
# 3     1454484512            nan      nan
# 4     1454484512            nan      nan

# %% [markdown]
# ### EDA

# %% [markdown]
# #### check for missing data in various columns

# %%
dataset_summary(merged_df,'age')
# Out:
# Top 10 age in dataset:
# age
# nan    219
# 64      52
# 57      16
# 75      15
# 21      13
# 20      12
# 31      11
# 27       8
# 42       8
# 25       8
# Name: count, dtype: int64

# %%
merged_df[['age','age_cod']].value_counts()
# Out:
# age  age_cod
# nan  nan        219
# 64   YR          52
# 57   YR          16
# 75   YR          15
# 20   YR          12
#                ...
# 44   YR           1
# 51   YR           1
# 91   YR           1
# 92   YR           1
# 48   YR           1
# Name: count, Length: 63, dtype: int64

# %%
merged_df['age_cod'].unique()
# Out:
# array(['YR', 'nan', 'MON', 'DEC'], dtype=object)

# %%
def convert_nan_to_npnan(df, column_name):
    df = df.copy()
    df[column_name] = df[column_name].replace(['nan', 'NaN', 'None'], np.nan)
    return df

# %%
convert_nan_to_npnan(merged_df,'age')
# Out:
#       primaryid    caseid                  drugname  event_dt  \
# 0    1454484512  14544845                CETIRIZINE  20110101
# 1    1454484512  14544845                CETIRIZINE  20110101
# 2    1454484512  14544845                CETIRIZINE  20110101
# 3    1454484512  14544845                CETIRIZINE  20110101
# 4    1454484512  14544845                CETIRIZINE  20110101
# ..          ...       ...                       ...       ...
# 530   247893501  24789350              FEXOFENADINE  20240710
# 531   247906781  24790678                CETIRIZINE  20240705
# 532   247919361  24791936  CETIRIZINE HYDROCHLORIDE  20241126
# 533   247953721  24795372                CETIRIZINE  20241126
# 534   247953841  24795384                CETIRIZINE  20230529
#
#                             pt  outc_cod drug_seq role_cod  \
# 0                   Drug abuse  OT,HO,LT        3       PS
# 1    Drug-induced liver injury  OT,HO,LT        3       PS
# 2             Hepatic necrosis  OT,HO,LT        3       PS
# 3         Intentional overdose  OT,HO,LT        3       PS
# 4                Off label use  OT,HO,LT        3       PS
# ..                         ...       ...      ...      ...
# 530                Skin lesion        OT        1       PS
# 531            Cardiac failure        HO        2       PS
# 532        Lichenoid keratosis        OT        1       PS
# 533        Lichenoid keratosis        OT        1       PS
# 534             Fixed eruption        HO        1       PS
#
#                         prod_ai val_vbm    route  \
# 0      CETIRIZINE HYDROCHLORIDE       1  Unknown
# 1      CETIRIZINE HYDROCHLORIDE       1  Unknown
# 2      CETIRIZINE HYDROCHLORIDE       1  Unknown
# 3      CETIRIZINE HYDROCHLORIDE       1  Unknown
# 4      CETIRIZINE HYDROCHLORIDE       1  Unknown
# ..                          ...     ...      ...
# 530  FEXOFENADINE HYDROCHLORIDE       1      nan
# 531    CETIRIZINE HYDROCHLORIDE       1     Oral
# 532    CETIRIZINE HYDROCHLORIDE       1     Oral
# 533    CETIRIZINE HYDROCHLORIDE       1     Oral
# 534    CETIRIZINE HYDROCHLORIDE       1     Oral
#
#                                               dose_vbm cum_dose_chr  \
# 0                                                  UNK          nan
# 1                                                  UNK          nan
# 2                                                  UNK          nan
# 3                                                  UNK          nan
# 4                                                  UNK          nan
# ..                                                 ...          ...
# 530  Increasing doses from 60 mgs OD to 240 mgs OD....          nan
# 531                           10 milligram, 1 cyclical          nan
# 532                                                nan          nan
# 533                                  1 dosage form, qd          nan
# 534                                  1 dosage form, qd          nan
#
#     cum_dose_unit dechal rechal            lot_num exp_dt nda_num dose_amt  \
# 0             nan      D    nan                nan    nan  090750      nan
# 1             nan      D    nan                nan    nan  090750      nan
# 2             nan      D    nan                nan    nan  090750      nan
# 3             nan      D    nan                nan    nan  090750      nan
# 4             nan      D    nan                nan    nan  090750      nan
# ..            ...    ...    ...                ...    ...     ...      ...
# 530           nan      N    nan  Asked But Unknown    nan  076502      nan
# 531           nan      D    nan                nan    nan  076677       10
# 532           nan      N    nan                nan    nan  019835      nan
# 533           nan      N    nan                nan    nan  076677      nan
# 534           nan      Y      Y                nan    nan  076677      nan
#
#     dose_unit           dose_form dose_freq primaryid_reac drug_rec_act  \
# 0         nan  Film-coated tablet       nan     1454484512          nan
# 1         nan  Film-coated tablet       nan     1454484512          nan
# 2         nan  Film-coated tablet       nan     1454484512          nan
# 3         nan  Film-coated tablet       nan     1454484512          nan
# 4         nan  Film-coated tablet       nan     1454484512          nan
# ..        ...                 ...       ...            ...          ...
# 530       nan                 nan       nan      247893501          nan
# 531        MG             Unknown       nan      247906781          nan
# 532       nan             Unknown        QD      247919361          nan
# 533       nan             Unknown        QD      247953721          nan
# 534       nan             Unknown        QD      247953841          nan
#
#     primaryid_demo caseversion i_f_code    mfr_dt init_fda_dt    fda_dt  \
# 0       1454484512          12        F  20240923    20180217  20241004
# 1       1454484512          12        F  20240923    20180217  20241004
# 2       1454484512          12        F  20240923    20180217  20241004
# 3       1454484512          12        F  20240923    20180217  20241004
# 4       1454484512          12        F  20240923    20180217  20241004
# ..             ...         ...      ...       ...         ...       ...
# 530      247893501           1        I  20241224    20241230  20241230
# 531      247906781           1        I  20241220    20241230  20241230
# 532      247919361           1        I  20241223    20241231  20241231
# 533      247953721           1        I  20241224    20241231  20241231
# 534      247953841           1        I  20241225    20241231  20241231
#
#     rept_cod                              auth_num  \
# 0        EXP                                   nan
# 1        EXP                                   nan
# 2        EXP                                   nan
# 3        EXP                                   nan
# 4        EXP                                   nan
# ..       ...                                   ...
# 530      EXP  GB-MHRA-MED-202412232351086500-CPWQY
# 531      EXP               FR-AFSSAPS-TS2024001547
# 532      EXP               FR-AFSSAPS-NY2024001489
# 533      EXP               FR-AFSSAPS-NY2024001489
# 534      EXP               FR-AFSSAPS-PC2024001043
#
#                               mfr_num   mfr_sndr  \
# 0    FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 1    FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 2    FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 3    FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 4    FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# ..                                ...        ...
# 530         GB-RDY-SPO/GBR/24/0019182  DR REDDYS
# 531         FR-MYLANLABS-2024M1115429      MYLAN
# 532             FR-KENVUE-20241207009     Kenvue
# 533         FR-MYLANLABS-2024M1116434      MYLAN
# 534         FR-MYLANLABS-2024M1116673      MYLAN
#
#                                                lit_ref  age age_cod age_grp  \
# 0    M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...   31      YR     nan
# 1    M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...   31      YR     nan
# 2    M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...   31      YR     nan
# 3    M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...   31      YR     nan
# 4    M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...   31      YR     nan
# ..                                                 ...  ...     ...     ...
# 530                                                nan   14      YR       T
# 531                                                nan   81      YR     nan
# 532                                                nan  NaN     nan     nan
# 533                                                nan   58      YR     nan
# 534                                                nan   44      YR     nan
#
#      sex e_sub   wt wt_cod   rept_dt to_mfr occp_cod reporter_country  \
# 0      F     Y  nan    nan  20241004    nan       MD               FR
# 1      F     Y  nan    nan  20241004    nan       MD               FR
# 2      F     Y  nan    nan  20241004    nan       MD               FR
# 3      F     Y  nan    nan  20241004    nan       MD               FR
# 4      F     Y  nan    nan  20241004    nan       MD               FR
# ..   ...   ...  ...    ...       ...    ...      ...              ...
# 530    M     Y  nan    nan  20241230    nan       CN               GB
# 531    F     Y   52     KG  20241230    nan       MD               FR
# 532  nan     Y  nan    nan  20241231    nan       MD               FR
# 533    F     Y  nan    nan  20241231    nan       MD               FR
# 534    M     Y   75     KG  20241231    nan       MD               FR
#
#     occr_country primaryid_outc primaryid_rpsr rpsr_cod
# 0             FR     1454484512            nan      nan
# 1             FR     1454484512            nan      nan
# 2             FR     1454484512            nan      nan
# 3             FR     1454484512            nan      nan
# 4             FR     1454484512            nan      nan
# ..           ...            ...            ...      ...
# 530           GB      247893501            nan      nan
# 531           FR      247906781            nan      nan
# 532           FR      247919361            nan      nan
# 533           FR      247953721            nan      nan
# 534           FR      247953841            nan      nan
#
# [535 rows x 51 columns]

# %%
merged_df[['age','age_cod']].value_counts()
# Out:
# age  age_cod
# nan  nan        219
# 64   YR          52
# 57   YR          16
# 75   YR          15
# 20   YR          12
#                ...
# 44   YR           1
# 51   YR           1
# 91   YR           1
# 92   YR           1
# 48   YR           1
# Name: count, Length: 63, dtype: int64

# %%
merged_df['age'] = pd.to_numeric(merged_df['age'], errors='coerce')

# %%
merged_df[['age']].value_counts()
# Out:
# age
# 64.0    52
# 57.0    16
# 75.0    15
# 21.0    13
# 20.0    12
# 31.0    11
# 42.0     8
# 86.0     8
# 32.0     8
# 27.0     8
# 25.0     8
# 53.0     8
# 72.0     7
# 50.0     7
# 22.0     7
# 54.0     7
# 15.0     7
# 81.0     6
# 5.0      6
# 3.0      6
# 12.0     6
# 14.0     5
# 47.0     5
# 4.0      5
# 55.0     4
# 33.0     4
# 89.0     4
# 52.0     3
# 66.0     3
# 28.0     3
# 78.0     3
# 29.0     3
# 23.0     3
# 82.0     3
# 17.0     3
# 13.0     3
# 68.0     2
# 79.0     2
# 65.0     2
# 62.0     2
# 1.0      2
# 46.0     2
# 58.0     2
# 2.0      2
# 19.0     2
# 37.0     2
# 43.0     2
# 41.0     2
# 44.0     1
# 67.0     1
# 76.0     1
# 56.0     1
# 48.0     1
# 80.0     1
# 51.0     1
# 18.0     1
# 11.0     1
# 7.0      1
# 91.0     1
# 92.0     1
# Name: count, dtype: int64

# %%
def type_conversion(df, column_name,tp):
    df[column_name] = df[column_name].astype(tp)

# %%
type_conversion(merged_df,'age','Int64')

# %%
merged_df.hist(column='age')
# Out:
# array([[<Axes: title={'center': 'age'}>]], dtype=object)

# %%
print("Missing age values:", merged_df['age'].isna().sum())
# Out:
# Missing age values: 219

# %%
# converting nan for age_cod to np.nan

# %%
convert_nan_to_npnan(merged_df,'age_cod')
# Out:
#       primaryid    caseid                  drugname  event_dt  \
# 0    1454484512  14544845                CETIRIZINE  20110101
# 1    1454484512  14544845                CETIRIZINE  20110101
# 2    1454484512  14544845                CETIRIZINE  20110101
# 3    1454484512  14544845                CETIRIZINE  20110101
# 4    1454484512  14544845                CETIRIZINE  20110101
# ..          ...       ...                       ...       ...
# 530   247893501  24789350              FEXOFENADINE  20240710
# 531   247906781  24790678                CETIRIZINE  20240705
# 532   247919361  24791936  CETIRIZINE HYDROCHLORIDE  20241126
# 533   247953721  24795372                CETIRIZINE  20241126
# 534   247953841  24795384                CETIRIZINE  20230529
#
#                             pt  outc_cod drug_seq role_cod  \
# 0                   Drug abuse  OT,HO,LT        3       PS
# 1    Drug-induced liver injury  OT,HO,LT        3       PS
# 2             Hepatic necrosis  OT,HO,LT        3       PS
# 3         Intentional overdose  OT,HO,LT        3       PS
# 4                Off label use  OT,HO,LT        3       PS
# ..                         ...       ...      ...      ...
# 530                Skin lesion        OT        1       PS
# 531            Cardiac failure        HO        2       PS
# 532        Lichenoid keratosis        OT        1       PS
# 533        Lichenoid keratosis        OT        1       PS
# 534             Fixed eruption        HO        1       PS
#
#                         prod_ai val_vbm    route  \
# 0      CETIRIZINE HYDROCHLORIDE       1  Unknown
# 1      CETIRIZINE HYDROCHLORIDE       1  Unknown
# 2      CETIRIZINE HYDROCHLORIDE       1  Unknown
# 3      CETIRIZINE HYDROCHLORIDE       1  Unknown
# 4      CETIRIZINE HYDROCHLORIDE       1  Unknown
# ..                          ...     ...      ...
# 530  FEXOFENADINE HYDROCHLORIDE       1      nan
# 531    CETIRIZINE HYDROCHLORIDE       1     Oral
# 532    CETIRIZINE HYDROCHLORIDE       1     Oral
# 533    CETIRIZINE HYDROCHLORIDE       1     Oral
# 534    CETIRIZINE HYDROCHLORIDE       1     Oral
#
#                                               dose_vbm cum_dose_chr  \
# 0                                                  UNK          nan
# 1                                                  UNK          nan
# 2                                                  UNK          nan
# 3                                                  UNK          nan
# 4                                                  UNK          nan
# ..                                                 ...          ...
# 530  Increasing doses from 60 mgs OD to 240 mgs OD....          nan
# 531                           10 milligram, 1 cyclical          nan
# 532                                                nan          nan
# 533                                  1 dosage form, qd          nan
# 534                                  1 dosage form, qd          nan
#
#     cum_dose_unit dechal rechal            lot_num exp_dt nda_num dose_amt  \
# 0             nan      D    nan                nan    nan  090750      nan
# 1             nan      D    nan                nan    nan  090750      nan
# 2             nan      D    nan                nan    nan  090750      nan
# 3             nan      D    nan                nan    nan  090750      nan
# 4             nan      D    nan                nan    nan  090750      nan
# ..            ...    ...    ...                ...    ...     ...      ...
# 530           nan      N    nan  Asked But Unknown    nan  076502      nan
# 531           nan      D    nan                nan    nan  076677       10
# 532           nan      N    nan                nan    nan  019835      nan
# 533           nan      N    nan                nan    nan  076677      nan
# 534           nan      Y      Y                nan    nan  076677      nan
#
#     dose_unit           dose_form dose_freq primaryid_reac drug_rec_act  \
# 0         nan  Film-coated tablet       nan     1454484512          nan
# 1         nan  Film-coated tablet       nan     1454484512          nan
# 2         nan  Film-coated tablet       nan     1454484512          nan
# 3         nan  Film-coated tablet       nan     1454484512          nan
# 4         nan  Film-coated tablet       nan     1454484512          nan
# ..        ...                 ...       ...            ...          ...
# 530       nan                 nan       nan      247893501          nan
# 531        MG             Unknown       nan      247906781          nan
# 532       nan             Unknown        QD      247919361          nan
# 533       nan             Unknown        QD      247953721          nan
# 534       nan             Unknown        QD      247953841          nan
#
#     primaryid_demo caseversion i_f_code    mfr_dt init_fda_dt    fda_dt  \
# 0       1454484512          12        F  20240923    20180217  20241004
# 1       1454484512          12        F  20240923    20180217  20241004
# 2       1454484512          12        F  20240923    20180217  20241004
# 3       1454484512          12        F  20240923    20180217  20241004
# 4       1454484512          12        F  20240923    20180217  20241004
# ..             ...         ...      ...       ...         ...       ...
# 530      247893501           1        I  20241224    20241230  20241230
# 531      247906781           1        I  20241220    20241230  20241230
# 532      247919361           1        I  20241223    20241231  20241231
# 533      247953721           1        I  20241224    20241231  20241231
# 534      247953841           1        I  20241225    20241231  20241231
#
#     rept_cod                              auth_num  \
# 0        EXP                                   nan
# 1        EXP                                   nan
# 2        EXP                                   nan
# 3        EXP                                   nan
# 4        EXP                                   nan
# ..       ...                                   ...
# 530      EXP  GB-MHRA-MED-202412232351086500-CPWQY
# 531      EXP               FR-AFSSAPS-TS2024001547
# 532      EXP               FR-AFSSAPS-NY2024001489
# 533      EXP               FR-AFSSAPS-NY2024001489
# 534      EXP               FR-AFSSAPS-PC2024001043
#
#                               mfr_num   mfr_sndr  \
# 0    FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 1    FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 2    FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 3    FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 4    FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# ..                                ...        ...
# 530         GB-RDY-SPO/GBR/24/0019182  DR REDDYS
# 531         FR-MYLANLABS-2024M1115429      MYLAN
# 532             FR-KENVUE-20241207009     Kenvue
# 533         FR-MYLANLABS-2024M1116434      MYLAN
# 534         FR-MYLANLABS-2024M1116673      MYLAN
#
#                                                lit_ref   age age_cod age_grp  \
# 0    M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...    31      YR     nan
# 1    M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...    31      YR     nan
# 2    M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...    31      YR     nan
# 3    M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...    31      YR     nan
# 4    M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...    31      YR     nan
# ..                                                 ...   ...     ...     ...
# 530                                                nan    14      YR       T
# 531                                                nan    81      YR     nan
# 532                                                nan  <NA>     NaN     nan
# 533                                                nan    58      YR     nan
# 534                                                nan    44      YR     nan
#
#      sex e_sub   wt wt_cod   rept_dt to_mfr occp_cod reporter_country  \
# 0      F     Y  nan    nan  20241004    nan       MD               FR
# 1      F     Y  nan    nan  20241004    nan       MD               FR
# 2      F     Y  nan    nan  20241004    nan       MD               FR
# 3      F     Y  nan    nan  20241004    nan       MD               FR
# 4      F     Y  nan    nan  20241004    nan       MD               FR
# ..   ...   ...  ...    ...       ...    ...      ...              ...
# 530    M     Y  nan    nan  20241230    nan       CN               GB
# 531    F     Y   52     KG  20241230    nan       MD               FR
# 532  nan     Y  nan    nan  20241231    nan       MD               FR
# 533    F     Y  nan    nan  20241231    nan       MD               FR
# 534    M     Y   75     KG  20241231    nan       MD               FR
#
#     occr_country primaryid_outc primaryid_rpsr rpsr_cod
# 0             FR     1454484512            nan      nan
# 1             FR     1454484512            nan      nan
# 2             FR     1454484512            nan      nan
# 3             FR     1454484512            nan      nan
# 4             FR     1454484512            nan      nan
# ..           ...            ...            ...      ...
# 530           GB      247893501            nan      nan
# 531           FR      247906781            nan      nan
# 532           FR      247919361            nan      nan
# 533           FR      247953721            nan      nan
# 534           FR      247953841            nan      nan
#
# [535 rows x 51 columns]

# %%
print("Missing age values:", merged_df['age_cod'].isna().sum())
# Out:
# Missing age values: 0

# %%
#Liu, R., et al. (2019). "Impact of Drug Normalization in FAERS for Detecting Safety Signals." Journal of Biomedical Informatics.
def convert_age_to_years(df):
    df = df.copy()  
    
    df['age'] = df['age'].astype(float)

    # Convert into years
    df.loc[df['age_cod'] == 'MON', 'age'] /= 12        # months 
    df.loc[df['age_cod'] == 'WK', 'age'] /= 52.1429    # weeks
    df.loc[df['age_cod'] == 'DY', 'age'] /= 365        # days
    df.loc[df['age_cod'] == 'HR', 'age'] /= 8760       # hours
    df.loc[df['age_cod'] == 'DEC', 'age'] *= 10        # decades

    return df

# %%
age_converted_df = convert_age_to_years(merged_df)

# %%
age_converted_df.hist(column='age')
# Out:
# array([[<Axes: title={'center': 'age'}>]], dtype=object)

# %%
print("Min age:", age_converted_df['age'].min())
print("Max age:", age_converted_df['age'].max())
# Out:
# Min age: 1.0
# Max age: 92.0

# %%
print("Missing ages after conversion:", age_converted_df['age'].isna().sum())
# Out:
# Missing ages after conversion: 219

# %%
print(age_converted_df[age_converted_df['age'] < 1]['age'].value_counts().head(10))
# Out:
# Series([], Name: count, dtype: int64)

# %%
#### need to handle the missing values in the age column, but based on which column??

# %%
drug_summary = age_converted_df.groupby('drugname')['age'].describe().round(2)
reaction_summary = age_converted_df.groupby('pt')['age'].describe().round(2)

# example drug 
drug_example = drug_summary.loc['CETIRIZINE']
reaction_example = reaction_summary.loc['Insomnia']

# comparison table

comparison_table = pd.DataFrame({
    'Metric': ['Count', 'Mean', 'Std', 'Min', '25%', '50% (Median)', '75%', 'Max'],
    'CETIRIZINE (Drug)': drug_example,
    'Insomnia (Reaction)': reaction_example
}).reset_index(drop=True)

comparison_table

# display(name="Drug vs Reaction Age Summary", dataframe=comparison_table)
# Out:
#          Metric  CETIRIZINE (Drug)  Insomnia (Reaction)
# 0         Count             102.00                 8.00
# 1          Mean              42.04                57.00
# 2           Std              21.79                14.97
# 3           Min               5.00                22.00
# 4           25%              20.00                60.50
# 5  50% (Median)              42.00                64.00
# 6           75%              64.00                64.00
# 7           Max              81.00                64.00

# %%
## exploring and pre-processing other columns to find the best column on whose basis imputation in age will be done

# %%
print("Unique drug names:", age_converted_df['drugname'].nunique())
print("Unique reaction terms (PT):", age_converted_df['pt'].nunique())

# Top 10 most common drugs
print(age_converted_df['drugname'].value_counts().head(10))

# Top 10 most common reactions
print(age_converted_df['pt'].value_counts().head(10))
# Out:
# Unique drug names: 12
# Unique reaction terms (PT): 242
# drugname
# CETIRIZINE                                                187
# CETIRIZINE HYDROCHLORIDE                                  133
# LORATADINE                                                 63
# FEXOFENADINE                                               40
# DESLORATADINE                                              37
# CHILDRENS CETIRIZINE HYDROCHLORIDE ALLERGY                 37
# CETIRIZINE HYDROCHLORIDE\PSEUDOEPHEDRINE HYDROCHLORIDE     13
# LEVOCETIRIZINE DIHYDROCHLORIDE                              9
# FEXOFENADINE HYDROCHLORIDE                                  7
# LORATADINE\PSEUDOEPHEDRINE SULFATE                          5
# Name: count, dtype: int64
# pt
# Off label use           14
# Anxiety                 13
# Insomnia                13
# Drug ineffective        11
# Malaise                 11
# Hypersensitivity         9
# Abdominal discomfort     9
# Rash                     9
# Pain of skin             9
# Somnolence               9
# Name: count, dtype: int64

# %%
age_converted_df['drugname'] = age_converted_df['drugname'].str.upper().str.strip()

# %%
age_converted_df['pt'] = age_converted_df['pt'].str.lower().str.strip()

# %%
print("Missing age values per drug:")
print(age_converted_df[age_converted_df['age'].isna()]['drugname'].value_counts().head(10))

print("Missing age values per reaction:")
print(age_converted_df[age_converted_df['age'].isna()]['pt'].value_counts().head(10))
# Out:
# Missing age values per drug:
# drugname
# CETIRIZINE HYDROCHLORIDE                      87
# CETIRIZINE                                    85
# LORATADINE                                    20
# CHILDRENS CETIRIZINE HYDROCHLORIDE ALLERGY    19
# DESLORATADINE                                  3
# LORATADINE\PSEUDOEPHEDRINE SULFATE             2
# LORATADINE AND PSEUDOEPHEDRINE SULFATE         2
# FEXOFENADINE HYDROCHLORIDE                     1
# Name: count, dtype: int64
# Missing age values per reaction:
# pt
# off label use                           9
# drug ineffective                        6
# anxiety                                 5
# insomnia                                5
# dyspnoea                                4
# pyrexia                                 3
# hypersensitivity                        3
# malaise                                 3
# product use in unapproved indication    3
# pain of skin                            3
# Name: count, dtype: int64

# %%
#### summaries based on reaction and drugs

# %%
drug_age_summary = age_converted_df.groupby('drugname')['age'].describe().sort_values(by='count', ascending=False).head(10)
print(drug_age_summary)
# Out:
#                                                     count       mean  \
# drugname
# CETIRIZINE                                          102.0  42.039216
# CETIRIZINE HYDROCHLORIDE                             46.0  53.125000
# LORATADINE                                           43.0  51.178295
# FEXOFENADINE                                         40.0  50.075000
# DESLORATADINE                                        34.0  50.147059
# CHILDRENS CETIRIZINE HYDROCHLORIDE ALLERGY           18.0  13.083333
# CETIRIZINE HYDROCHLORIDE\PSEUDOEPHEDRINE HYDROC...   13.0  35.230769
# LEVOCETIRIZINE DIHYDROCHLORIDE                        9.0  45.444444
# FEXOFENADINE HYDROCHLORIDE                            6.0  55.833333
# LORATADINE\PSEUDOEPHEDRINE SULFATE                    3.0  52.000000
#
#                                                           std        min  \
# drugname
# CETIRIZINE                                          21.794232   5.000000
# CETIRIZINE HYDROCHLORIDE                            24.593948   1.916667
# LORATADINE                                          25.198508   2.333333
# FEXOFENADINE                                        24.055904  14.000000
# DESLORATADINE                                       24.307540   7.000000
# CHILDRENS CETIRIZINE HYDROCHLORIDE ALLERGY          24.373322   1.000000
# CETIRIZINE HYDROCHLORIDE\PSEUDOEPHEDRINE HYDROC...  14.376798  22.000000
# LEVOCETIRIZINE DIHYDROCHLORIDE                      19.698421  27.000000
# FEXOFENADINE HYDROCHLORIDE                          11.513760  43.000000
# LORATADINE\PSEUDOEPHEDRINE SULFATE                   0.000000  52.000000
#
#                                                      25%   50%   75%   max
# drugname
# CETIRIZINE                                          20.0  42.0  64.0  81.0
# CETIRIZINE HYDROCHLORIDE                            31.0  64.0  64.0  86.0
# LORATADINE                                          29.0  57.0  73.5  82.0
# FEXOFENADINE                                        26.5  50.0  75.0  91.0
# DESLORATADINE                                       33.0  53.0  54.0  92.0
# CHILDRENS CETIRIZINE HYDROCHLORIDE ALLERGY           2.0   3.0  12.5  79.0
# CETIRIZINE HYDROCHLORIDE\PSEUDOEPHEDRINE HYDROC...  22.0  32.0  55.0  55.0
# LEVOCETIRIZINE DIHYDROCHLORIDE                      27.0  48.0  57.0  82.0
# FEXOFENADINE HYDROCHLORIDE                          45.0  58.5  66.0  66.0
# LORATADINE\PSEUDOEPHEDRINE SULFATE                  52.0  52.0  52.0  52.0

# %%
# Get summary statistics for Age grouped by PT (Reaction)
reaction_age_summary = age_converted_df.groupby('pt')['age'].describe().sort_values(by='count', ascending=False).head(10)
print(reaction_age_summary)
# Out:
#                              count       mean        std        min    25%  \
# pt
# incorrect dose administered    9.0  26.435185  28.098715   1.916667   3.00
# insomnia                       8.0  57.000000  14.966630  22.000000  60.50
# anxiety                        8.0  57.375000  13.968715  25.000000  60.50
# malaise                        8.0  53.625000  19.360767  18.000000  54.75
# somnolence                     7.0  26.142857  12.979838  20.000000  20.00
# rash                           7.0  12.857143  19.886583   1.000000   4.00
# skin irritation                6.0  64.000000   0.000000  64.000000  64.00
# pruritus                       6.0  65.833333  13.347909  56.000000  57.00
# drug withdrawal syndrome       6.0  64.000000   0.000000  64.000000  64.00
# pain of skin                   6.0  64.000000   0.000000  64.000000  64.00
#
#                               50%   75%   max
# pt
# incorrect dose administered  11.0  47.0  75.0
# insomnia                     64.0  64.0  64.0
# anxiety                      64.0  64.0  64.0
# malaise                      64.0  64.0  64.0
# somnolence                   20.0  24.0  55.0
# rash                          5.0   9.5  57.0
# skin irritation              64.0  64.0  64.0
# pruritus                     61.5  67.5  91.0
# drug withdrawal syndrome     64.0  64.0  64.0
# pain of skin                 64.0  64.0  64.0

# %%
## I am able to see some patterns between drug and age rather than reaction and age. for example skin irritation is only seen on 64 years old thus reaction may not be a suitable column for imputation

# %%
median_age_by_drug = age_converted_df.groupby('drugname')['age'].median()
age_converted_df['age'] = age_converted_df.apply(lambda row: median_age_by_drug[row['drugname']] if pd.isna(row['age']) else row['age'], axis=1)

# %%
age_converted_df[age_converted_df['age'].isna()].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
convert_nan_to_npnan(age_converted_df,'event_dt')
# Out:
#       primaryid    caseid                  drugname  event_dt  \
# 0    1454484512  14544845                CETIRIZINE  20110101
# 1    1454484512  14544845                CETIRIZINE  20110101
# 2    1454484512  14544845                CETIRIZINE  20110101
# 3    1454484512  14544845                CETIRIZINE  20110101
# 4    1454484512  14544845                CETIRIZINE  20110101
# ..          ...       ...                       ...       ...
# 530   247893501  24789350              FEXOFENADINE  20240710
# 531   247906781  24790678                CETIRIZINE  20240705
# 532   247919361  24791936  CETIRIZINE HYDROCHLORIDE  20241126
# 533   247953721  24795372                CETIRIZINE  20241126
# 534   247953841  24795384                CETIRIZINE  20230529
#
#                             pt  outc_cod drug_seq role_cod  \
# 0                   drug abuse  OT,HO,LT        3       PS
# 1    drug-induced liver injury  OT,HO,LT        3       PS
# 2             hepatic necrosis  OT,HO,LT        3       PS
# 3         intentional overdose  OT,HO,LT        3       PS
# 4                off label use  OT,HO,LT        3       PS
# ..                         ...       ...      ...      ...
# 530                skin lesion        OT        1       PS
# 531            cardiac failure        HO        2       PS
# 532        lichenoid keratosis        OT        1       PS
# 533        lichenoid keratosis        OT        1       PS
# 534             fixed eruption        HO        1       PS
#
#                         prod_ai val_vbm    route  \
# 0      CETIRIZINE HYDROCHLORIDE       1  Unknown
# 1      CETIRIZINE HYDROCHLORIDE       1  Unknown
# 2      CETIRIZINE HYDROCHLORIDE       1  Unknown
# 3      CETIRIZINE HYDROCHLORIDE       1  Unknown
# 4      CETIRIZINE HYDROCHLORIDE       1  Unknown
# ..                          ...     ...      ...
# 530  FEXOFENADINE HYDROCHLORIDE       1      nan
# 531    CETIRIZINE HYDROCHLORIDE       1     Oral
# 532    CETIRIZINE HYDROCHLORIDE       1     Oral
# 533    CETIRIZINE HYDROCHLORIDE       1     Oral
# 534    CETIRIZINE HYDROCHLORIDE       1     Oral
#
#                                               dose_vbm cum_dose_chr  \
# 0                                                  UNK          nan
# 1                                                  UNK          nan
# 2                                                  UNK          nan
# 3                                                  UNK          nan
# 4                                                  UNK          nan
# ..                                                 ...          ...
# 530  Increasing doses from 60 mgs OD to 240 mgs OD....          nan
# 531                           10 milligram, 1 cyclical          nan
# 532                                                nan          nan
# 533                                  1 dosage form, qd          nan
# 534                                  1 dosage form, qd          nan
#
#     cum_dose_unit dechal rechal            lot_num exp_dt nda_num dose_amt  \
# 0             nan      D    nan                nan    nan  090750      nan
# 1             nan      D    nan                nan    nan  090750      nan
# 2             nan      D    nan                nan    nan  090750      nan
# 3             nan      D    nan                nan    nan  090750      nan
# 4             nan      D    nan                nan    nan  090750      nan
# ..            ...    ...    ...                ...    ...     ...      ...
# 530           nan      N    nan  Asked But Unknown    nan  076502      nan
# 531           nan      D    nan                nan    nan  076677       10
# 532           nan      N    nan                nan    nan  019835      nan
# 533           nan      N    nan                nan    nan  076677      nan
# 534           nan      Y      Y                nan    nan  076677      nan
#
#     dose_unit           dose_form dose_freq primaryid_reac drug_rec_act  \
# 0         nan  Film-coated tablet       nan     1454484512          nan
# 1         nan  Film-coated tablet       nan     1454484512          nan
# 2         nan  Film-coated tablet       nan     1454484512          nan
# 3         nan  Film-coated tablet       nan     1454484512          nan
# 4         nan  Film-coated tablet       nan     1454484512          nan
# ..        ...                 ...       ...            ...          ...
# 530       nan                 nan       nan      247893501          nan
# 531        MG             Unknown       nan      247906781          nan
# 532       nan             Unknown        QD      247919361          nan
# 533       nan             Unknown        QD      247953721          nan
# 534       nan             Unknown        QD      247953841          nan
#
#     primaryid_demo caseversion i_f_code    mfr_dt init_fda_dt    fda_dt  \
# 0       1454484512          12        F  20240923    20180217  20241004
# 1       1454484512          12        F  20240923    20180217  20241004
# 2       1454484512          12        F  20240923    20180217  20241004
# 3       1454484512          12        F  20240923    20180217  20241004
# 4       1454484512          12        F  20240923    20180217  20241004
# ..             ...         ...      ...       ...         ...       ...
# 530      247893501           1        I  20241224    20241230  20241230
# 531      247906781           1        I  20241220    20241230  20241230
# 532      247919361           1        I  20241223    20241231  20241231
# 533      247953721           1        I  20241224    20241231  20241231
# 534      247953841           1        I  20241225    20241231  20241231
#
#     rept_cod                              auth_num  \
# 0        EXP                                   nan
# 1        EXP                                   nan
# 2        EXP                                   nan
# 3        EXP                                   nan
# 4        EXP                                   nan
# ..       ...                                   ...
# 530      EXP  GB-MHRA-MED-202412232351086500-CPWQY
# 531      EXP               FR-AFSSAPS-TS2024001547
# 532      EXP               FR-AFSSAPS-NY2024001489
# 533      EXP               FR-AFSSAPS-NY2024001489
# 534      EXP               FR-AFSSAPS-PC2024001043
#
#                               mfr_num   mfr_sndr  \
# 0    FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 1    FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 2    FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 3    FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 4    FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# ..                                ...        ...
# 530         GB-RDY-SPO/GBR/24/0019182  DR REDDYS
# 531         FR-MYLANLABS-2024M1115429      MYLAN
# 532             FR-KENVUE-20241207009     Kenvue
# 533         FR-MYLANLABS-2024M1116434      MYLAN
# 534         FR-MYLANLABS-2024M1116673      MYLAN
#
#                                                lit_ref   age age_cod age_grp  \
# 0    M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31.0      YR     nan
# 1    M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31.0      YR     nan
# 2    M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31.0      YR     nan
# 3    M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31.0      YR     nan
# 4    M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31.0      YR     nan
# ..                                                 ...   ...     ...     ...
# 530                                                nan  14.0      YR       T
# 531                                                nan  81.0      YR     nan
# 532                                                nan  64.0     nan     nan
# 533                                                nan  58.0      YR     nan
# 534                                                nan  44.0      YR     nan
#
#      sex e_sub   wt wt_cod   rept_dt to_mfr occp_cod reporter_country  \
# 0      F     Y  nan    nan  20241004    nan       MD               FR
# 1      F     Y  nan    nan  20241004    nan       MD               FR
# 2      F     Y  nan    nan  20241004    nan       MD               FR
# 3      F     Y  nan    nan  20241004    nan       MD               FR
# 4      F     Y  nan    nan  20241004    nan       MD               FR
# ..   ...   ...  ...    ...       ...    ...      ...              ...
# 530    M     Y  nan    nan  20241230    nan       CN               GB
# 531    F     Y   52     KG  20241230    nan       MD               FR
# 532  nan     Y  nan    nan  20241231    nan       MD               FR
# 533    F     Y  nan    nan  20241231    nan       MD               FR
# 534    M     Y   75     KG  20241231    nan       MD               FR
#
#     occr_country primaryid_outc primaryid_rpsr rpsr_cod
# 0             FR     1454484512            nan      nan
# 1             FR     1454484512            nan      nan
# 2             FR     1454484512            nan      nan
# 3             FR     1454484512            nan      nan
# 4             FR     1454484512            nan      nan
# ..           ...            ...            ...      ...
# 530           GB      247893501            nan      nan
# 531           FR      247906781            nan      nan
# 532           FR      247919361            nan      nan
# 533           FR      247953721            nan      nan
# 534           FR      247953841            nan      nan
#
# [535 rows x 51 columns]

# %%
convert_nan_to_npnan(age_converted_df,'pt')
# Out:
#       primaryid    caseid                  drugname  event_dt  \
# 0    1454484512  14544845                CETIRIZINE  20110101
# 1    1454484512  14544845                CETIRIZINE  20110101
# 2    1454484512  14544845                CETIRIZINE  20110101
# 3    1454484512  14544845                CETIRIZINE  20110101
# 4    1454484512  14544845                CETIRIZINE  20110101
# ..          ...       ...                       ...       ...
# 530   247893501  24789350              FEXOFENADINE  20240710
# 531   247906781  24790678                CETIRIZINE  20240705
# 532   247919361  24791936  CETIRIZINE HYDROCHLORIDE  20241126
# 533   247953721  24795372                CETIRIZINE  20241126
# 534   247953841  24795384                CETIRIZINE  20230529
#
#                             pt  outc_cod drug_seq role_cod  \
# 0                   drug abuse  OT,HO,LT        3       PS
# 1    drug-induced liver injury  OT,HO,LT        3       PS
# 2             hepatic necrosis  OT,HO,LT        3       PS
# 3         intentional overdose  OT,HO,LT        3       PS
# 4                off label use  OT,HO,LT        3       PS
# ..                         ...       ...      ...      ...
# 530                skin lesion        OT        1       PS
# 531            cardiac failure        HO        2       PS
# 532        lichenoid keratosis        OT        1       PS
# 533        lichenoid keratosis        OT        1       PS
# 534             fixed eruption        HO        1       PS
#
#                         prod_ai val_vbm    route  \
# 0      CETIRIZINE HYDROCHLORIDE       1  Unknown
# 1      CETIRIZINE HYDROCHLORIDE       1  Unknown
# 2      CETIRIZINE HYDROCHLORIDE       1  Unknown
# 3      CETIRIZINE HYDROCHLORIDE       1  Unknown
# 4      CETIRIZINE HYDROCHLORIDE       1  Unknown
# ..                          ...     ...      ...
# 530  FEXOFENADINE HYDROCHLORIDE       1      nan
# 531    CETIRIZINE HYDROCHLORIDE       1     Oral
# 532    CETIRIZINE HYDROCHLORIDE       1     Oral
# 533    CETIRIZINE HYDROCHLORIDE       1     Oral
# 534    CETIRIZINE HYDROCHLORIDE       1     Oral
#
#                                               dose_vbm cum_dose_chr  \
# 0                                                  UNK          nan
# 1                                                  UNK          nan
# 2                                                  UNK          nan
# 3                                                  UNK          nan
# 4                                                  UNK          nan
# ..                                                 ...          ...
# 530  Increasing doses from 60 mgs OD to 240 mgs OD....          nan
# 531                           10 milligram, 1 cyclical          nan
# 532                                                nan          nan
# 533                                  1 dosage form, qd          nan
# 534                                  1 dosage form, qd          nan
#
#     cum_dose_unit dechal rechal            lot_num exp_dt nda_num dose_amt  \
# 0             nan      D    nan                nan    nan  090750      nan
# 1             nan      D    nan                nan    nan  090750      nan
# 2             nan      D    nan                nan    nan  090750      nan
# 3             nan      D    nan                nan    nan  090750      nan
# 4             nan      D    nan                nan    nan  090750      nan
# ..            ...    ...    ...                ...    ...     ...      ...
# 530           nan      N    nan  Asked But Unknown    nan  076502      nan
# 531           nan      D    nan                nan    nan  076677       10
# 532           nan      N    nan                nan    nan  019835      nan
# 533           nan      N    nan                nan    nan  076677      nan
# 534           nan      Y      Y                nan    nan  076677      nan
#
#     dose_unit           dose_form dose_freq primaryid_reac drug_rec_act  \
# 0         nan  Film-coated tablet       nan     1454484512          nan
# 1         nan  Film-coated tablet       nan     1454484512          nan
# 2         nan  Film-coated tablet       nan     1454484512          nan
# 3         nan  Film-coated tablet       nan     1454484512          nan
# 4         nan  Film-coated tablet       nan     1454484512          nan
# ..        ...                 ...       ...            ...          ...
# 530       nan                 nan       nan      247893501          nan
# 531        MG             Unknown       nan      247906781          nan
# 532       nan             Unknown        QD      247919361          nan
# 533       nan             Unknown        QD      247953721          nan
# 534       nan             Unknown        QD      247953841          nan
#
#     primaryid_demo caseversion i_f_code    mfr_dt init_fda_dt    fda_dt  \
# 0       1454484512          12        F  20240923    20180217  20241004
# 1       1454484512          12        F  20240923    20180217  20241004
# 2       1454484512          12        F  20240923    20180217  20241004
# 3       1454484512          12        F  20240923    20180217  20241004
# 4       1454484512          12        F  20240923    20180217  20241004
# ..             ...         ...      ...       ...         ...       ...
# 530      247893501           1        I  20241224    20241230  20241230
# 531      247906781           1        I  20241220    20241230  20241230
# 532      247919361           1        I  20241223    20241231  20241231
# 533      247953721           1        I  20241224    20241231  20241231
# 534      247953841           1        I  20241225    20241231  20241231
#
#     rept_cod                              auth_num  \
# 0        EXP                                   nan
# 1        EXP                                   nan
# 2        EXP                                   nan
# 3        EXP                                   nan
# 4        EXP                                   nan
# ..       ...                                   ...
# 530      EXP  GB-MHRA-MED-202412232351086500-CPWQY
# 531      EXP               FR-AFSSAPS-TS2024001547
# 532      EXP               FR-AFSSAPS-NY2024001489
# 533      EXP               FR-AFSSAPS-NY2024001489
# 534      EXP               FR-AFSSAPS-PC2024001043
#
#                               mfr_num   mfr_sndr  \
# 0    FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 1    FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 2    FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 3    FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 4    FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# ..                                ...        ...
# 530         GB-RDY-SPO/GBR/24/0019182  DR REDDYS
# 531         FR-MYLANLABS-2024M1115429      MYLAN
# 532             FR-KENVUE-20241207009     Kenvue
# 533         FR-MYLANLABS-2024M1116434      MYLAN
# 534         FR-MYLANLABS-2024M1116673      MYLAN
#
#                                                lit_ref   age age_cod age_grp  \
# 0    M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31.0      YR     nan
# 1    M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31.0      YR     nan
# 2    M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31.0      YR     nan
# 3    M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31.0      YR     nan
# 4    M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31.0      YR     nan
# ..                                                 ...   ...     ...     ...
# 530                                                nan  14.0      YR       T
# 531                                                nan  81.0      YR     nan
# 532                                                nan  64.0     nan     nan
# 533                                                nan  58.0      YR     nan
# 534                                                nan  44.0      YR     nan
#
#      sex e_sub   wt wt_cod   rept_dt to_mfr occp_cod reporter_country  \
# 0      F     Y  nan    nan  20241004    nan       MD               FR
# 1      F     Y  nan    nan  20241004    nan       MD               FR
# 2      F     Y  nan    nan  20241004    nan       MD               FR
# 3      F     Y  nan    nan  20241004    nan       MD               FR
# 4      F     Y  nan    nan  20241004    nan       MD               FR
# ..   ...   ...  ...    ...       ...    ...      ...              ...
# 530    M     Y  nan    nan  20241230    nan       CN               GB
# 531    F     Y   52     KG  20241230    nan       MD               FR
# 532  nan     Y  nan    nan  20241231    nan       MD               FR
# 533    F     Y  nan    nan  20241231    nan       MD               FR
# 534    M     Y   75     KG  20241231    nan       MD               FR
#
#     occr_country primaryid_outc primaryid_rpsr rpsr_cod
# 0             FR     1454484512            nan      nan
# 1             FR     1454484512            nan      nan
# 2             FR     1454484512            nan      nan
# 3             FR     1454484512            nan      nan
# 4             FR     1454484512            nan      nan
# ..           ...            ...            ...      ...
# 530           GB      247893501            nan      nan
# 531           FR      247906781            nan      nan
# 532           FR      247919361            nan      nan
# 533           FR      247953721            nan      nan
# 534           FR      247953841            nan      nan
#
# [535 rows x 51 columns]

# %%
convert_nan_to_npnan(age_converted_df,'sex')
# Out:
#       primaryid    caseid                  drugname  event_dt  \
# 0    1454484512  14544845                CETIRIZINE  20110101
# 1    1454484512  14544845                CETIRIZINE  20110101
# 2    1454484512  14544845                CETIRIZINE  20110101
# 3    1454484512  14544845                CETIRIZINE  20110101
# 4    1454484512  14544845                CETIRIZINE  20110101
# ..          ...       ...                       ...       ...
# 530   247893501  24789350              FEXOFENADINE  20240710
# 531   247906781  24790678                CETIRIZINE  20240705
# 532   247919361  24791936  CETIRIZINE HYDROCHLORIDE  20241126
# 533   247953721  24795372                CETIRIZINE  20241126
# 534   247953841  24795384                CETIRIZINE  20230529
#
#                             pt  outc_cod drug_seq role_cod  \
# 0                   drug abuse  OT,HO,LT        3       PS
# 1    drug-induced liver injury  OT,HO,LT        3       PS
# 2             hepatic necrosis  OT,HO,LT        3       PS
# 3         intentional overdose  OT,HO,LT        3       PS
# 4                off label use  OT,HO,LT        3       PS
# ..                         ...       ...      ...      ...
# 530                skin lesion        OT        1       PS
# 531            cardiac failure        HO        2       PS
# 532        lichenoid keratosis        OT        1       PS
# 533        lichenoid keratosis        OT        1       PS
# 534             fixed eruption        HO        1       PS
#
#                         prod_ai val_vbm    route  \
# 0      CETIRIZINE HYDROCHLORIDE       1  Unknown
# 1      CETIRIZINE HYDROCHLORIDE       1  Unknown
# 2      CETIRIZINE HYDROCHLORIDE       1  Unknown
# 3      CETIRIZINE HYDROCHLORIDE       1  Unknown
# 4      CETIRIZINE HYDROCHLORIDE       1  Unknown
# ..                          ...     ...      ...
# 530  FEXOFENADINE HYDROCHLORIDE       1      nan
# 531    CETIRIZINE HYDROCHLORIDE       1     Oral
# 532    CETIRIZINE HYDROCHLORIDE       1     Oral
# 533    CETIRIZINE HYDROCHLORIDE       1     Oral
# 534    CETIRIZINE HYDROCHLORIDE       1     Oral
#
#                                               dose_vbm cum_dose_chr  \
# 0                                                  UNK          nan
# 1                                                  UNK          nan
# 2                                                  UNK          nan
# 3                                                  UNK          nan
# 4                                                  UNK          nan
# ..                                                 ...          ...
# 530  Increasing doses from 60 mgs OD to 240 mgs OD....          nan
# 531                           10 milligram, 1 cyclical          nan
# 532                                                nan          nan
# 533                                  1 dosage form, qd          nan
# 534                                  1 dosage form, qd          nan
#
#     cum_dose_unit dechal rechal            lot_num exp_dt nda_num dose_amt  \
# 0             nan      D    nan                nan    nan  090750      nan
# 1             nan      D    nan                nan    nan  090750      nan
# 2             nan      D    nan                nan    nan  090750      nan
# 3             nan      D    nan                nan    nan  090750      nan
# 4             nan      D    nan                nan    nan  090750      nan
# ..            ...    ...    ...                ...    ...     ...      ...
# 530           nan      N    nan  Asked But Unknown    nan  076502      nan
# 531           nan      D    nan                nan    nan  076677       10
# 532           nan      N    nan                nan    nan  019835      nan
# 533           nan      N    nan                nan    nan  076677      nan
# 534           nan      Y      Y                nan    nan  076677      nan
#
#     dose_unit           dose_form dose_freq primaryid_reac drug_rec_act  \
# 0         nan  Film-coated tablet       nan     1454484512          nan
# 1         nan  Film-coated tablet       nan     1454484512          nan
# 2         nan  Film-coated tablet       nan     1454484512          nan
# 3         nan  Film-coated tablet       nan     1454484512          nan
# 4         nan  Film-coated tablet       nan     1454484512          nan
# ..        ...                 ...       ...            ...          ...
# 530       nan                 nan       nan      247893501          nan
# 531        MG             Unknown       nan      247906781          nan
# 532       nan             Unknown        QD      247919361          nan
# 533       nan             Unknown        QD      247953721          nan
# 534       nan             Unknown        QD      247953841          nan
#
#     primaryid_demo caseversion i_f_code    mfr_dt init_fda_dt    fda_dt  \
# 0       1454484512          12        F  20240923    20180217  20241004
# 1       1454484512          12        F  20240923    20180217  20241004
# 2       1454484512          12        F  20240923    20180217  20241004
# 3       1454484512          12        F  20240923    20180217  20241004
# 4       1454484512          12        F  20240923    20180217  20241004
# ..             ...         ...      ...       ...         ...       ...
# 530      247893501           1        I  20241224    20241230  20241230
# 531      247906781           1        I  20241220    20241230  20241230
# 532      247919361           1        I  20241223    20241231  20241231
# 533      247953721           1        I  20241224    20241231  20241231
# 534      247953841           1        I  20241225    20241231  20241231
#
#     rept_cod                              auth_num  \
# 0        EXP                                   nan
# 1        EXP                                   nan
# 2        EXP                                   nan
# 3        EXP                                   nan
# 4        EXP                                   nan
# ..       ...                                   ...
# 530      EXP  GB-MHRA-MED-202412232351086500-CPWQY
# 531      EXP               FR-AFSSAPS-TS2024001547
# 532      EXP               FR-AFSSAPS-NY2024001489
# 533      EXP               FR-AFSSAPS-NY2024001489
# 534      EXP               FR-AFSSAPS-PC2024001043
#
#                               mfr_num   mfr_sndr  \
# 0    FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 1    FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 2    FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 3    FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 4    FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# ..                                ...        ...
# 530         GB-RDY-SPO/GBR/24/0019182  DR REDDYS
# 531         FR-MYLANLABS-2024M1115429      MYLAN
# 532             FR-KENVUE-20241207009     Kenvue
# 533         FR-MYLANLABS-2024M1116434      MYLAN
# 534         FR-MYLANLABS-2024M1116673      MYLAN
#
#                                                lit_ref   age age_cod age_grp  \
# 0    M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31.0      YR     nan
# 1    M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31.0      YR     nan
# 2    M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31.0      YR     nan
# 3    M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31.0      YR     nan
# 4    M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31.0      YR     nan
# ..                                                 ...   ...     ...     ...
# 530                                                nan  14.0      YR       T
# 531                                                nan  81.0      YR     nan
# 532                                                nan  64.0     nan     nan
# 533                                                nan  58.0      YR     nan
# 534                                                nan  44.0      YR     nan
#
#      sex e_sub   wt wt_cod   rept_dt to_mfr occp_cod reporter_country  \
# 0      F     Y  nan    nan  20241004    nan       MD               FR
# 1      F     Y  nan    nan  20241004    nan       MD               FR
# 2      F     Y  nan    nan  20241004    nan       MD               FR
# 3      F     Y  nan    nan  20241004    nan       MD               FR
# 4      F     Y  nan    nan  20241004    nan       MD               FR
# ..   ...   ...  ...    ...       ...    ...      ...              ...
# 530    M     Y  nan    nan  20241230    nan       CN               GB
# 531    F     Y   52     KG  20241230    nan       MD               FR
# 532  NaN     Y  nan    nan  20241231    nan       MD               FR
# 533    F     Y  nan    nan  20241231    nan       MD               FR
# 534    M     Y   75     KG  20241231    nan       MD               FR
#
#     occr_country primaryid_outc primaryid_rpsr rpsr_cod
# 0             FR     1454484512            nan      nan
# 1             FR     1454484512            nan      nan
# 2             FR     1454484512            nan      nan
# 3             FR     1454484512            nan      nan
# 4             FR     1454484512            nan      nan
# ..           ...            ...            ...      ...
# 530           GB      247893501            nan      nan
# 531           FR      247906781            nan      nan
# 532           FR      247919361            nan      nan
# 533           FR      247953721            nan      nan
# 534           FR      247953841            nan      nan
#
# [535 rows x 51 columns]

# %%
age_converted_df['sex'].isna().sum()
# Out:
# 0

# %%
age_converted_df[age_converted_df['sex'].isna()]
# Out:
# Empty DataFrame
# Columns: [primaryid, caseid, drugname, event_dt, pt, outc_cod, drug_seq, role_cod, prod_ai, val_vbm, route, dose_vbm, cum_dose_chr, cum_dose_unit, dechal, rechal, lot_num, exp_dt, nda_num, dose_amt, dose_unit, dose_form, dose_freq, primaryid_reac, drug_rec_act, primaryid_demo, caseversion, i_f_code, mfr_dt, init_fda_dt, fda_dt, rept_cod, auth_num, mfr_num, mfr_sndr, lit_ref, age, age_cod, age_grp, sex, e_sub, wt, wt_cod, rept_dt, to_mfr, occp_cod, reporter_country, occr_country, primaryid_outc, primaryid_rpsr, rpsr_cod]
# Index: []

# %%
age_converted_df.columns
# Out:
# Index(['primaryid', 'caseid', 'drugname', 'event_dt', 'pt', 'outc_cod',
#        'drug_seq', 'role_cod', 'prod_ai', 'val_vbm', 'route', 'dose_vbm',
#        'cum_dose_chr', 'cum_dose_unit', 'dechal', 'rechal', 'lot_num',
#        'exp_dt', 'nda_num', 'dose_amt', 'dose_unit', 'dose_form', 'dose_freq',
#        'primaryid_reac', 'drug_rec_act', 'primaryid_demo', 'caseversion',
#        'i_f_code', 'mfr_dt', 'init_fda_dt', 'fda_dt', 'rept_cod', 'auth_num',
#        'mfr_num', 'mfr_sndr', 'lit_ref', 'age', 'age_cod', 'age_grp', 'sex',
#        'e_sub', 'wt', 'wt_cod', 'rept_dt', 'to_mfr', 'occp_cod',
#        'reporter_country', 'occr_country', 'primaryid_outc', 'primaryid_rpsr',
#        'rpsr_cod'],
#       dtype='object')

# %%
age_converted_df.shape[0]
# Out:
# 535

# %%
### there are missing sex data and imputing them at random might cause bias
### will follow the approach as mentioned by Fang, H., et al. (2014). Exploring the FDA Adverse Event Reporting System (FAERS) to Generate Hypotheses for Monitoring of Disease Characteristics. Clinical Pharmacology & Therapeutics, 95(5).

# %%
print("Total missing values in SEX:", age_converted_df['sex'].isna().sum())
print("SEX distribution in non-missing cases:")
print(age_converted_df['sex'].value_counts(normalize=True))
# Out:
# Total missing values in SEX: 0
# SEX distribution in non-missing cases:
# sex
# F      0.403738
# M      0.310280
# nan    0.285981
# Name: proportion, dtype: float64

# %%
print('drugs with most missing sex values')
print(age_converted_df[age_converted_df['sex'].isna()]['drugname'].value_counts().head(10))
# Out:
# drugs with most missing sex values
# Series([], Name: count, dtype: int64)

# %%
print('reactions with most missing sex values')
print(age_converted_df[age_converted_df['sex'].isna()]['pt'].value_counts().head(10))
# Out:
# reactions with most missing sex values
# Series([], Name: count, dtype: int64)

# %%
age_converted_df[age_converted_df['sex']=='nan'].head(5)
# Out:
#     primaryid    caseid                  drugname  event_dt  \
# 13  199237056  19923705  CETIRIZINE HYDROCHLORIDE  20180829
# 14  199237056  19923705  CETIRIZINE HYDROCHLORIDE  20180829
# 15  199237056  19923705  CETIRIZINE HYDROCHLORIDE  20180829
# 16  199237056  19923705  CETIRIZINE HYDROCHLORIDE  20180829
# 17  199237056  19923705  CETIRIZINE HYDROCHLORIDE  20180829
#
#                             pt outc_cod drug_seq role_cod  \
# 13                    alopecia       OT        1       PS
# 14    blood pressure increased       OT        1       PS
# 15  body temperature increased       OT        1       PS
# 16                  bronchitis       OT        1       PS
# 17                    covid-19       OT        1       PS
#
#                      prod_ai val_vbm    route                  dose_vbm  \
# 13  CETIRIZINE HYDROCHLORIDE       1  Unknown  1 dosage form, as needed
# 14  CETIRIZINE HYDROCHLORIDE       1  Unknown  1 dosage form, as needed
# 15  CETIRIZINE HYDROCHLORIDE       1  Unknown  1 dosage form, as needed
# 16  CETIRIZINE HYDROCHLORIDE       1  Unknown  1 dosage form, as needed
# 17  CETIRIZINE HYDROCHLORIDE       1  Unknown  1 dosage form, as needed
#
#    cum_dose_chr cum_dose_unit dechal rechal lot_num exp_dt nda_num dose_amt  \
# 13          nan           nan      U    nan     nan    nan  019835      nan
# 14          nan           nan      U    nan     nan    nan  019835      nan
# 15          nan           nan      U    nan     nan    nan  019835      nan
# 16          nan           nan      U    nan     nan    nan  019835      nan
# 17          nan           nan      U    nan     nan    nan  019835      nan
#
#    dose_unit dose_form dose_freq primaryid_reac drug_rec_act primaryid_demo  \
# 13       nan   Unknown       nan      199237056          nan      199237056
# 14       nan   Unknown       nan      199237056          nan      199237056
# 15       nan   Unknown       nan      199237056          nan      199237056
# 16       nan   Unknown       nan      199237056          nan      199237056
# 17       nan   Unknown       nan      199237056          nan      199237056
#
#    caseversion i_f_code    mfr_dt init_fda_dt    fda_dt rept_cod auth_num  \
# 13           6        F  20241119    20211006  20241128      EXP      nan
# 14           6        F  20241119    20211006  20241128      EXP      nan
# 15           6        F  20241119    20211006  20241128      EXP      nan
# 16           6        F  20241119    20211006  20241128      EXP      nan
# 17           6        F  20241119    20211006  20241128      EXP      nan
#
#                   mfr_num mfr_sndr lit_ref   age age_cod age_grp  sex e_sub  \
# 13  DE-JNJFOC-20190707481   Kenvue     nan  64.0     nan     nan  nan     Y
# 14  DE-JNJFOC-20190707481   Kenvue     nan  64.0     nan     nan  nan     Y
# 15  DE-JNJFOC-20190707481   Kenvue     nan  64.0     nan     nan  nan     Y
# 16  DE-JNJFOC-20190707481   Kenvue     nan  64.0     nan     nan  nan     Y
# 17  DE-JNJFOC-20190707481   Kenvue     nan  64.0     nan     nan  nan     Y
#
#      wt wt_cod   rept_dt to_mfr occp_cod reporter_country occr_country  \
# 13  nan    nan  20241128    nan       CN               DE           DE
# 14  nan    nan  20241128    nan       CN               DE           DE
# 15  nan    nan  20241128    nan       CN               DE           DE
# 16  nan    nan  20241128    nan       CN               DE           DE
# 17  nan    nan  20241128    nan       CN               DE           DE
#
#    primaryid_outc primaryid_rpsr rpsr_cod
# 13      199237056            nan      nan
# 14      199237056            nan      nan
# 15      199237056            nan      nan
# 16      199237056            nan      nan
# 17      199237056            nan      nan

# %%
df_with_sex = age_converted_df[age_converted_df['sex']!='nan']  # Remove missing SEX
df_with_unknown = age_converted_df.copy()
df_with_unknown['sex'].fillna("Unknown", inplace=True)

# Compare outcome rates
print("Outcome distribution without missing SEX:")
print(df_with_sex['outc_cod'].value_counts(normalize=True))

print("Outcome distribution with 'Unknown' SEX:")
print(df_with_unknown['outc_cod'].value_counts(normalize=True))
# Out:
# Outcome distribution without missing SEX:
# outc_cod
# OT                         0.376963
#                            0.227749
# DS,OT                      0.094241
# HO                         0.086387
# OT,DS                      0.041885
# LT                         0.036649
# HO,OT                      0.034031
# LT,OT                      0.018325
# OT,HO,LT                   0.015707
# LT,OT,HO,DS                0.013089
# HO,LT,OT                   0.013089
# CA                         0.010471
# HO,OT,HO,OT                0.007853
# OT,HO                      0.007853
# RI,OT                      0.007853
# DS                         0.005236
# LT,OT,HO,DS,LT,OT,HO,DS    0.002618
# Name: proportion, dtype: float64
# Outcome distribution with 'Unknown' SEX:
# outc_cod
# OT                         0.459813
#                            0.177570
# HO                         0.084112
# DS,OT                      0.082243
# OT,DS                      0.046729
# HO,OT                      0.037383
# LT                         0.026168
# LT,OT                      0.013084
# OT,HO,LT                   0.011215
# LT,OT,HO,DS                0.009346
# HO,LT,OT                   0.009346
# CA                         0.007477
# LT,HO                      0.007477
# OT,HO                      0.007477
# HO,OT,HO,OT                0.005607
# RI,OT                      0.005607
# OT,OT                      0.003738
# DS                         0.003738
# LT,OT,HO,DS,LT,OT,HO,DS    0.001869
# Name: proportion, dtype: float64
# C:\Users\utsav\AppData\Local\Temp\ipykernel_18928\3861979457.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_with_unknown['sex'].fillna("Unknown", inplace=True)

# %%
#### from what i see after the sensitivity analysis the value of outc_cod changes when "unknown" sex is introduced
### suggesting if i were to impute the value of sex, bias might be introduced in the data, so leaving Nan as Unknown

# %%
age_converted_df['sex'].fillna("Unknown", inplace=True)
# Out:
# C:\Users\utsav\AppData\Local\Temp\ipykernel_30292\2949259767.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   age_converted_df['sex'].fillna("Unknown", inplace=True)

# %%
age_converted_df['sex'].isna().sum()
# Out:
# 0

# %%
age_converted_df['pt'].isna().sum()
# Out:
# 0

# %%
## sources for drug name normalization

## https://www.researchgate.net/publication/49967730_Methods_for_Managing_Variation_in_Clinical_Drug_Names
## https://pubmed.ncbi.nlm.nih.gov/38250436/
## https://europepmc.org/article/pmc/3041346
## https://bmcmedinformdecismak.biomedcentral.com/articles/10.1186/1472-6947-12-9
## https://academic.oup.com/bioinformatics/article/40/3/btae085/7612228?login=false
## https://www.frontiersin.org/journals/bioinformatics/articles/10.3389/fbinf.2023.1328613/full
## https://pmc.ncbi.nlm.nih.gov/articles/PMC3128404/
## https://medinform.jmir.org/2020/2/e14777/
## https://www.medrxiv.org/content/10.1101/2023.07.27.23293245v1.full
## https://academic.oup.com/jamiaopen/article/6/4/ooad093/7388192?login=false
## https://pubmed.ncbi.nlm.nih.gov/38250436/

# %%
age_converted_df['drugname'].unique()
# Out:
# array(['CETIRIZINE', 'CETIRIZINE HYDROCHLORIDE', 'DESLORATADINE',
#        'LORATADINE', 'FEXOFENADINE HYDROCHLORIDE',
#        'CHILDRENS CETIRIZINE HYDROCHLORIDE ALLERGY',
#        'LEVOCETIRIZINE DIHYDROCHLORIDE',
#        'LORATADINE\\PSEUDOEPHEDRINE SULFATE',
#        'LORATADINE AND PSEUDOEPHEDRINE SULFATE', 'FEXOFENADINE',
#        'LEVOCETIRIZINE',
#        'CETIRIZINE HYDROCHLORIDE\\PSEUDOEPHEDRINE HYDROCHLORIDE'],
#       dtype=object)

# %%
age_converted_df['pt'].unique()
# Out:
# array(['drug abuse', 'drug-induced liver injury', 'hepatic necrosis',
#        'intentional overdose', 'off label use', 'suicide attempt',
#        'condition aggravated', 'epidermolysis bullosa', 'leukopenia',
#        'lymphopenia', 'product use in unapproved indication',
#        'toxic epidermal necrolysis', 'alopecia',
#        'blood pressure increased', 'body temperature increased',
#        'bronchitis', 'covid-19', 'cough', 'dyspnoea', 'ear pain',
#        'fatigue', 'gastrointestinal infection', 'hot flush',
#        'hypoaesthesia', 'infection susceptibility increased',
#        'nasal congestion', 'nasopharyngitis', 'palpitations',
#        'paraesthesia', 'pustule', 'pyrexia', 'intentional product misuse',
#        'intentional product use issue', 'subarachnoid haemorrhage',
#        'congenital genital malformation female',
#        'foetal exposure during pregnancy', 'abdominal discomfort',
#        'abdominal pain upper', 'adverse drug reaction', 'amnesia',
#        'angioedema', 'anosmia', 'anxiety', 'arthralgia',
#        'atrial tachycardia', 'back pain', 'blindness',
#        'blood glucose increased', 'cardiospasm',
#        'carotid artery occlusion', 'chest pain', 'cognitive disorder',
#        'dehydration', 'diarrhoea', 'diplopia', 'disturbance in attention',
#        'dizziness', 'dry skin', 'eye pruritus', 'facial pain',
#        'feeling abnormal', 'hallucination', 'headache',
#        'heart rate increased', 'hyperhidrosis', 'immunisation',
#        'insomnia', 'lip swelling', 'malaise', 'memory impairment',
#        'migraine', 'muscle twitching', 'muscular weakness',
#        'myocardial infarction', 'nausea', 'pain', 'pain of skin',
#        'palmoplantar keratoderma', 'pericarditis', 'peripheral swelling',
#        'pruritus', 'pruritus genital', 'rash papular', 'sleep terror',
#        'tachycardia', 'tension headache', 'tinnitus',
#        'transient ischaemic attack', 'vasculitis',
#        'ventricular tachycardia', 'visual impairment', 'vomiting',
#        'drug reaction with eosinophilia and systemic symptoms', 'ageusia',
#        'drug ineffective', 'gingival pain', 'hypoaesthesia oral',
#        'lymphadenopathy', 'mouth swelling', 'stomatitis', 'swelling face',
#        'acute myocardial infarction', 'arteriospasm coronary',
#        'resuscitation', 'ventricular fibrillation',
#        'amniotic fluid index increased',
#        'maternal exposure during pregnancy', 'asphyxia',
#        'pulmonary embolism', 'rash', 'somnolence',
#        'oesophageal achalasia', 'therapeutic product effect decreased',
#        'dry mouth', 'irritability', 'muscle spasms', 'nervousness',
#        'oropharyngeal pain', 'incorrect dose administered',
#        'exposure to unspecified agent',
#        'accidental exposure to product by child',
#        'product administered to patient of inappropriate age',
#        'expired product administered', 'extra dose administered',
#        'underdose', 'tremor', 'hallucination, auditory',
#        'chest discomfort', 'poor quality product administered',
#        'product physical issue', 'drug screen positive',
#        'drug withdrawal syndrome', 'hypersensitivity', 'skin irritation',
#        'anaemia', 'asthenia', 'cholestatic liver injury',
#        'interstitial lung disease', 'pancytopenia',
#        'coordination abnormal', 'hallucination, visual', 'depressed mood',
#        'confusional state', 'thrombocytopenia', 'chemical submission',
#        'fall', 'head injury', 'ligament sprain', 'spinal fracture',
#        'exposure during pregnancy',
#        'inappropriate schedule of product administration',
#        'pre-eclampsia', 'agranulocytosis', 'periorbital oedema',
#        'productive cough', 'sleep disorder', 'weight increased',
#        'drug eruption', 'swelling', 'burning sensation', 'rash macular',
#        'skin burning sensation', 'caesarean section', 'constipation',
#        'decreased appetite', 'dysphonia', 'musculoskeletal chest pain',
#        'urinary retention', 'conjunctivitis allergic',
#        'self-injurious ideation', 'bronchospasm', 'herpes zoster',
#        'urticaria', 'hypotonia', 'victim of chemical submission',
#        'epilepsy', 'seizure', 'incontinence', 'loss of consciousness',
#        'syncope', 'injection site erythema', 'injection site haemorrhage',
#        'injection site irritation', 'insurance issue',
#        'therapy interrupted', 'rash maculo-papular', 'depression',
#        'alopecia areata', 'depressed level of consciousness', 'bone pain',
#        'ligament disorder', 'ligament pain', 'localised oedema',
#        'muscle oedema', 'myalgia', 'periarthritis', 'skin induration',
#        'sneezing', 'tendon disorder', 'tendon pain',
#        'heart rate irregular', 'medication error', 'dystonia', 'myokymia',
#        'nervous system disorder', 'amenorrhoea', 'hypotension',
#        'wrong technique in product usage process', 'product after taste',
#        'product use complaint', 'dermatitis bullous',
#        'injection site mass', 'drug effect less than expected',
#        'respiratory disorder', 'feeling hot', 'feeling jittery',
#        'ischaemic stroke', 'hepatitis cholestatic', 'asthma',
#        'chronic obstructive pulmonary disease', 'hypertension', 'rales',
#        'stress', 'aphasia', 'balance disorder', 'gait disturbance',
#        'visual field defect', 'product label issue', 'therapy cessation',
#        'substance use disorder', 'extrasystoles', 'skin mass',
#        'cardiac failure', 'delirium', 'disorientation', 'abdominal pain',
#        'severe cutaneous adverse reaction', 'skin discharge',
#        'skin haemorrhage', 'skin lesion', 'lichenoid keratosis',
#        'fixed eruption'], dtype=object)

# %%
age_converted_df.shape[0]
# Out:
# 535

# %%
age_converted_df.columns
# Out:
# Index(['primaryid', 'caseid', 'drugname', 'event_dt', 'pt', 'outc_cod',
#        'drug_seq', 'role_cod', 'prod_ai', 'val_vbm', 'route', 'dose_vbm',
#        'cum_dose_chr', 'cum_dose_unit', 'dechal', 'rechal', 'lot_num',
#        'exp_dt', 'nda_num', 'dose_amt', 'dose_unit', 'dose_form', 'dose_freq',
#        'primaryid_reac', 'drug_rec_act', 'primaryid_demo', 'caseversion',
#        'i_f_code', 'mfr_dt', 'init_fda_dt', 'fda_dt', 'rept_cod', 'auth_num',
#        'mfr_num', 'mfr_sndr', 'lit_ref', 'age', 'age_cod', 'age_grp', 'sex',
#        'e_sub', 'wt', 'wt_cod', 'rept_dt', 'to_mfr', 'occp_cod',
#        'reporter_country', 'occr_country', 'primaryid_outc', 'primaryid_rpsr',
#        'rpsr_cod'],
#       dtype='object')

# %%
import requests

def normalize_drug_names(df, column='drugname'):
    """
    Normalize drug names using the RxNorm API.

    Parameters:
    df (pd.DataFrame): DataFrame containing drug names.
    column (str): Column name with drug names to normalize.

    Returns:
    pd.DataFrame: DataFrame with an additional column for normalized drug names.
    """
    base_url = 'https://rxnav.nlm.nih.gov/REST/rxcui.json?name='

    def get_rxnorm_name(drug_name):
        try:
            response = requests.get(base_url + drug_name)
            response.raise_for_status()
            data = response.json()
            if 'idGroup' in data and 'name' in data['idGroup']:
                return data['idGroup']['name']
            else:
                return drug_name
        except requests.RequestException as e:
            print(f"Error fetching RxNorm name for {drug_name}: {e}")
            return drug_name

    # Apply the RxNorm mapping to each drug name
    df['normalized_drugname'] = df[column].apply(get_rxnorm_name)
    return df

# %%
normalized_df = normalize_drug_names(age_converted_df)

# %%
normalized_df.columns
# Out:
# Index(['primaryid', 'caseid', 'drugname', 'event_dt', 'pt', 'outc_cod',
#        'drug_seq', 'role_cod', 'prod_ai', 'val_vbm', 'route', 'dose_vbm',
#        'cum_dose_chr', 'cum_dose_unit', 'dechal', 'rechal', 'lot_num',
#        'exp_dt', 'nda_num', 'dose_amt', 'dose_unit', 'dose_form', 'dose_freq',
#        'primaryid_reac', 'drug_rec_act', 'primaryid_demo', 'caseversion',
#        'i_f_code', 'mfr_dt', 'init_fda_dt', 'fda_dt', 'rept_cod', 'auth_num',
#        'mfr_num', 'mfr_sndr', 'lit_ref', 'age', 'age_cod', 'age_grp', 'sex',
#        'e_sub', 'wt', 'wt_cod', 'rept_dt', 'to_mfr', 'occp_cod',
#        'reporter_country', 'occr_country', 'primaryid_outc', 'primaryid_rpsr',
#        'rpsr_cod', 'normalized_drugname'],
#       dtype='object')

# %%
normalized_df['normalized_drugname'
              ].unique()
# Out:
# array(['CETIRIZINE', 'CETIRIZINE HYDROCHLORIDE', 'DESLORATADINE',
#        'LORATADINE', 'FEXOFENADINE HYDROCHLORIDE',
#        'CHILDRENS CETIRIZINE HYDROCHLORIDE ALLERGY',
#        'LEVOCETIRIZINE DIHYDROCHLORIDE',
#        'LORATADINE\\PSEUDOEPHEDRINE SULFATE',
#        'LORATADINE AND PSEUDOEPHEDRINE SULFATE', 'FEXOFENADINE',
#        'LEVOCETIRIZINE',
#        'CETIRIZINE HYDROCHLORIDE\\PSEUDOEPHEDRINE HYDROCHLORIDE'],
#       dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
sns.boxplot(x='normalized_drugname', y='dose_amt', data=normalized_df)
plt.xticks(rotation=90)
plt.title("Dosage Distribution Across Drugs")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
sns.boxplot(x='normalized_drugname', y='dose_amt', data=normalized_df)
plt.xticks(rotation=90)
plt.title("Dosage Distribution Across Drugs")
plt.show()

# %%
print(normalized_df[normalized_df['dose_amt'].isna()]['normalized_drugname'].value_counts().head(10))
# Out:
# Series([], Name: count, dtype: int64)

# %%
convert_nan_to_npnan(normalized_df,'dose_amt')
# Out:
#       primaryid    caseid                  drugname  event_dt  \
# 0    1454484512  14544845                CETIRIZINE  20110101
# 1    1454484512  14544845                CETIRIZINE  20110101
# 2    1454484512  14544845                CETIRIZINE  20110101
# 3    1454484512  14544845                CETIRIZINE  20110101
# 4    1454484512  14544845                CETIRIZINE  20110101
# ..          ...       ...                       ...       ...
# 530   247893501  24789350              FEXOFENADINE  20240710
# 531   247906781  24790678                CETIRIZINE  20240705
# 532   247919361  24791936  CETIRIZINE HYDROCHLORIDE  20241126
# 533   247953721  24795372                CETIRIZINE  20241126
# 534   247953841  24795384                CETIRIZINE  20230529
#
#                             pt  outc_cod drug_seq role_cod  \
# 0                   drug abuse  OT,HO,LT        3       PS
# 1    drug-induced liver injury  OT,HO,LT        3       PS
# 2             hepatic necrosis  OT,HO,LT        3       PS
# 3         intentional overdose  OT,HO,LT        3       PS
# 4                off label use  OT,HO,LT        3       PS
# ..                         ...       ...      ...      ...
# 530                skin lesion        OT        1       PS
# 531            cardiac failure        HO        2       PS
# 532        lichenoid keratosis        OT        1       PS
# 533        lichenoid keratosis        OT        1       PS
# 534             fixed eruption        HO        1       PS
#
#                         prod_ai val_vbm    route  \
# 0      CETIRIZINE HYDROCHLORIDE       1  Unknown
# 1      CETIRIZINE HYDROCHLORIDE       1  Unknown
# 2      CETIRIZINE HYDROCHLORIDE       1  Unknown
# 3      CETIRIZINE HYDROCHLORIDE       1  Unknown
# 4      CETIRIZINE HYDROCHLORIDE       1  Unknown
# ..                          ...     ...      ...
# 530  FEXOFENADINE HYDROCHLORIDE       1      nan
# 531    CETIRIZINE HYDROCHLORIDE       1     Oral
# 532    CETIRIZINE HYDROCHLORIDE       1     Oral
# 533    CETIRIZINE HYDROCHLORIDE       1     Oral
# 534    CETIRIZINE HYDROCHLORIDE       1     Oral
#
#                                               dose_vbm cum_dose_chr  \
# 0                                                  UNK          nan
# 1                                                  UNK          nan
# 2                                                  UNK          nan
# 3                                                  UNK          nan
# 4                                                  UNK          nan
# ..                                                 ...          ...
# 530  Increasing doses from 60 mgs OD to 240 mgs OD....          nan
# 531                           10 milligram, 1 cyclical          nan
# 532                                                nan          nan
# 533                                  1 dosage form, qd          nan
# 534                                  1 dosage form, qd          nan
#
#     cum_dose_unit dechal rechal            lot_num exp_dt nda_num dose_amt  \
# 0             nan      D    nan                nan    nan  090750      NaN
# 1             nan      D    nan                nan    nan  090750      NaN
# 2             nan      D    nan                nan    nan  090750      NaN
# 3             nan      D    nan                nan    nan  090750      NaN
# 4             nan      D    nan                nan    nan  090750      NaN
# ..            ...    ...    ...                ...    ...     ...      ...
# 530           nan      N    nan  Asked But Unknown    nan  076502      NaN
# 531           nan      D    nan                nan    nan  076677       10
# 532           nan      N    nan                nan    nan  019835      NaN
# 533           nan      N    nan                nan    nan  076677      NaN
# 534           nan      Y      Y                nan    nan  076677      NaN
#
#     dose_unit           dose_form dose_freq primaryid_reac drug_rec_act  \
# 0         nan  Film-coated tablet       nan     1454484512          nan
# 1         nan  Film-coated tablet       nan     1454484512          nan
# 2         nan  Film-coated tablet       nan     1454484512          nan
# 3         nan  Film-coated tablet       nan     1454484512          nan
# 4         nan  Film-coated tablet       nan     1454484512          nan
# ..        ...                 ...       ...            ...          ...
# 530       nan                 nan       nan      247893501          nan
# 531        MG             Unknown       nan      247906781          nan
# 532       nan             Unknown        QD      247919361          nan
# 533       nan             Unknown        QD      247953721          nan
# 534       nan             Unknown        QD      247953841          nan
#
#     primaryid_demo caseversion i_f_code    mfr_dt init_fda_dt    fda_dt  \
# 0       1454484512          12        F  20240923    20180217  20241004
# 1       1454484512          12        F  20240923    20180217  20241004
# 2       1454484512          12        F  20240923    20180217  20241004
# 3       1454484512          12        F  20240923    20180217  20241004
# 4       1454484512          12        F  20240923    20180217  20241004
# ..             ...         ...      ...       ...         ...       ...
# 530      247893501           1        I  20241224    20241230  20241230
# 531      247906781           1        I  20241220    20241230  20241230
# 532      247919361           1        I  20241223    20241231  20241231
# 533      247953721           1        I  20241224    20241231  20241231
# 534      247953841           1        I  20241225    20241231  20241231
#
#     rept_cod                              auth_num  \
# 0        EXP                                   nan
# 1        EXP                                   nan
# 2        EXP                                   nan
# 3        EXP                                   nan
# 4        EXP                                   nan
# ..       ...                                   ...
# 530      EXP  GB-MHRA-MED-202412232351086500-CPWQY
# 531      EXP               FR-AFSSAPS-TS2024001547
# 532      EXP               FR-AFSSAPS-NY2024001489
# 533      EXP               FR-AFSSAPS-NY2024001489
# 534      EXP               FR-AFSSAPS-PC2024001043
#
#                               mfr_num   mfr_sndr  \
# 0    FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 1    FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 2    FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 3    FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 4    FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# ..                                ...        ...
# 530         GB-RDY-SPO/GBR/24/0019182  DR REDDYS
# 531         FR-MYLANLABS-2024M1115429      MYLAN
# 532             FR-KENVUE-20241207009     Kenvue
# 533         FR-MYLANLABS-2024M1116434      MYLAN
# 534         FR-MYLANLABS-2024M1116673      MYLAN
#
#                                                lit_ref   age age_cod age_grp  \
# 0    M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31.0      YR     nan
# 1    M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31.0      YR     nan
# 2    M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31.0      YR     nan
# 3    M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31.0      YR     nan
# 4    M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31.0      YR     nan
# ..                                                 ...   ...     ...     ...
# 530                                                nan  14.0      YR       T
# 531                                                nan  81.0      YR     nan
# 532                                                nan  64.0     nan     nan
# 533                                                nan  58.0      YR     nan
# 534                                                nan  44.0      YR     nan
#
#      sex e_sub   wt wt_cod   rept_dt to_mfr occp_cod reporter_country  \
# 0      F     Y  nan    nan  20241004    nan       MD               FR
# 1      F     Y  nan    nan  20241004    nan       MD               FR
# 2      F     Y  nan    nan  20241004    nan       MD               FR
# 3      F     Y  nan    nan  20241004    nan       MD               FR
# 4      F     Y  nan    nan  20241004    nan       MD               FR
# ..   ...   ...  ...    ...       ...    ...      ...              ...
# 530    M     Y  nan    nan  20241230    nan       CN               GB
# 531    F     Y   52     KG  20241230    nan       MD               FR
# 532  nan     Y  nan    nan  20241231    nan       MD               FR
# 533    F     Y  nan    nan  20241231    nan       MD               FR
# 534    M     Y   75     KG  20241231    nan       MD               FR
#
#     occr_country primaryid_outc primaryid_rpsr rpsr_cod  \
# 0             FR     1454484512            nan      nan
# 1             FR     1454484512            nan      nan
# 2             FR     1454484512            nan      nan
# 3             FR     1454484512            nan      nan
# 4             FR     1454484512            nan      nan
# ..           ...            ...            ...      ...
# 530           GB      247893501            nan      nan
# 531           FR      247906781            nan      nan
# 532           FR      247919361            nan      nan
# 533           FR      247953721            nan      nan
# 534           FR      247953841            nan      nan
#
#           normalized_drugname
# 0                  CETIRIZINE
# 1                  CETIRIZINE
# 2                  CETIRIZINE
# 3                  CETIRIZINE
# 4                  CETIRIZINE
# ..                        ...
# 530              FEXOFENADINE
# 531                CETIRIZINE
# 532  CETIRIZINE HYDROCHLORIDE
# 533                CETIRIZINE
# 534                CETIRIZINE
#
# [535 rows x 52 columns]

# %%
normalized_df.groupby('normalized_drugname')['dose_amt'].describe().sort_values(by='count', ascending=False).head(10)
# Out:
#                                                    count unique  top freq
# normalized_drugname
# CETIRIZINE                                           187      3   10  128
# CETIRIZINE HYDROCHLORIDE                             133      4   10   67
# LORATADINE                                            63      4  nan   30
# FEXOFENADINE                                          40      3  nan   22
# CHILDRENS CETIRIZINE HYDROCHLORIDE ALLERGY            37      6    5   16
# DESLORATADINE                                         37      3    5   26
# CETIRIZINE HYDROCHLORIDE\PSEUDOEPHEDRINE HYDROC...    13      1  nan   13
# LEVOCETIRIZINE DIHYDROCHLORIDE                         9      1  nan    9
# FEXOFENADINE HYDROCHLORIDE                             7      2  180    4
# LORATADINE\PSEUDOEPHEDRINE SULFATE                     5      1  nan    5

# %%
normalized_df['dose_amt'].max()
# Out:
# 'nan'

# %%
def convert_str_to_float(df, column_name):
    df = df.copy()
    df[column_name] = pd.to_numeric(df[column_name], errors='coerce')  # Ensures NaNs instead of errors
    return df

# %%
new_df = convert_str_to_float(normalized_df,'dose_amt')

# %%
new_df[new_df['dose_amt']!=10.0][['dose_amt','dose_unit','normalized_drugname']]
# Out:
#      dose_amt dose_unit       normalized_drugname
# 0         NaN       nan                CETIRIZINE
# 1         NaN       nan                CETIRIZINE
# 2         NaN       nan                CETIRIZINE
# 3         NaN       nan                CETIRIZINE
# 4         NaN       nan                CETIRIZINE
# ..        ...       ...                       ...
# 529       NaN       nan              FEXOFENADINE
# 530       NaN       nan              FEXOFENADINE
# 532       NaN       nan  CETIRIZINE HYDROCHLORIDE
# 533       NaN       nan                CETIRIZINE
# 534       NaN       nan                CETIRIZINE
#
# [314 rows x 3 columns]

# %%
new_df['dose_amt'].max()
# Out:
# 180.0

# %%
convert_nan_to_npnan(new_df,'dose_amt')
# Out:
#       primaryid    caseid                  drugname  event_dt  \
# 0    1454484512  14544845                CETIRIZINE  20110101
# 1    1454484512  14544845                CETIRIZINE  20110101
# 2    1454484512  14544845                CETIRIZINE  20110101
# 3    1454484512  14544845                CETIRIZINE  20110101
# 4    1454484512  14544845                CETIRIZINE  20110101
# ..          ...       ...                       ...       ...
# 530   247893501  24789350              FEXOFENADINE  20240710
# 531   247906781  24790678                CETIRIZINE  20240705
# 532   247919361  24791936  CETIRIZINE HYDROCHLORIDE  20241126
# 533   247953721  24795372                CETIRIZINE  20241126
# 534   247953841  24795384                CETIRIZINE  20230529
#
#                             pt  outc_cod drug_seq role_cod  \
# 0                   drug abuse  OT,HO,LT        3       PS
# 1    drug-induced liver injury  OT,HO,LT        3       PS
# 2             hepatic necrosis  OT,HO,LT        3       PS
# 3         intentional overdose  OT,HO,LT        3       PS
# 4                off label use  OT,HO,LT        3       PS
# ..                         ...       ...      ...      ...
# 530                skin lesion        OT        1       PS
# 531            cardiac failure        HO        2       PS
# 532        lichenoid keratosis        OT        1       PS
# 533        lichenoid keratosis        OT        1       PS
# 534             fixed eruption        HO        1       PS
#
#                         prod_ai val_vbm    route  \
# 0      CETIRIZINE HYDROCHLORIDE       1  Unknown
# 1      CETIRIZINE HYDROCHLORIDE       1  Unknown
# 2      CETIRIZINE HYDROCHLORIDE       1  Unknown
# 3      CETIRIZINE HYDROCHLORIDE       1  Unknown
# 4      CETIRIZINE HYDROCHLORIDE       1  Unknown
# ..                          ...     ...      ...
# 530  FEXOFENADINE HYDROCHLORIDE       1      nan
# 531    CETIRIZINE HYDROCHLORIDE       1     Oral
# 532    CETIRIZINE HYDROCHLORIDE       1     Oral
# 533    CETIRIZINE HYDROCHLORIDE       1     Oral
# 534    CETIRIZINE HYDROCHLORIDE       1     Oral
#
#                                               dose_vbm cum_dose_chr  \
# 0                                                  UNK          nan
# 1                                                  UNK          nan
# 2                                                  UNK          nan
# 3                                                  UNK          nan
# 4                                                  UNK          nan
# ..                                                 ...          ...
# 530  Increasing doses from 60 mgs OD to 240 mgs OD....          nan
# 531                           10 milligram, 1 cyclical          nan
# 532                                                nan          nan
# 533                                  1 dosage form, qd          nan
# 534                                  1 dosage form, qd          nan
#
#     cum_dose_unit dechal rechal            lot_num exp_dt nda_num  dose_amt  \
# 0             nan      D    nan                nan    nan  090750       NaN
# 1             nan      D    nan                nan    nan  090750       NaN
# 2             nan      D    nan                nan    nan  090750       NaN
# 3             nan      D    nan                nan    nan  090750       NaN
# 4             nan      D    nan                nan    nan  090750       NaN
# ..            ...    ...    ...                ...    ...     ...       ...
# 530           nan      N    nan  Asked But Unknown    nan  076502       NaN
# 531           nan      D    nan                nan    nan  076677      10.0
# 532           nan      N    nan                nan    nan  019835       NaN
# 533           nan      N    nan                nan    nan  076677       NaN
# 534           nan      Y      Y                nan    nan  076677       NaN
#
#     dose_unit           dose_form dose_freq primaryid_reac drug_rec_act  \
# 0         nan  Film-coated tablet       nan     1454484512          nan
# 1         nan  Film-coated tablet       nan     1454484512          nan
# 2         nan  Film-coated tablet       nan     1454484512          nan
# 3         nan  Film-coated tablet       nan     1454484512          nan
# 4         nan  Film-coated tablet       nan     1454484512          nan
# ..        ...                 ...       ...            ...          ...
# 530       nan                 nan       nan      247893501          nan
# 531        MG             Unknown       nan      247906781          nan
# 532       nan             Unknown        QD      247919361          nan
# 533       nan             Unknown        QD      247953721          nan
# 534       nan             Unknown        QD      247953841          nan
#
#     primaryid_demo caseversion i_f_code    mfr_dt init_fda_dt    fda_dt  \
# 0       1454484512          12        F  20240923    20180217  20241004
# 1       1454484512          12        F  20240923    20180217  20241004
# 2       1454484512          12        F  20240923    20180217  20241004
# 3       1454484512          12        F  20240923    20180217  20241004
# 4       1454484512          12        F  20240923    20180217  20241004
# ..             ...         ...      ...       ...         ...       ...
# 530      247893501           1        I  20241224    20241230  20241230
# 531      247906781           1        I  20241220    20241230  20241230
# 532      247919361           1        I  20241223    20241231  20241231
# 533      247953721           1        I  20241224    20241231  20241231
# 534      247953841           1        I  20241225    20241231  20241231
#
#     rept_cod                              auth_num  \
# 0        EXP                                   nan
# 1        EXP                                   nan
# 2        EXP                                   nan
# 3        EXP                                   nan
# 4        EXP                                   nan
# ..       ...                                   ...
# 530      EXP  GB-MHRA-MED-202412232351086500-CPWQY
# 531      EXP               FR-AFSSAPS-TS2024001547
# 532      EXP               FR-AFSSAPS-NY2024001489
# 533      EXP               FR-AFSSAPS-NY2024001489
# 534      EXP               FR-AFSSAPS-PC2024001043
#
#                               mfr_num   mfr_sndr  \
# 0    FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 1    FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 2    FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 3    FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# 4    FR-AUROBINDO-AUR-APL-2018-007959  AUROBINDO
# ..                                ...        ...
# 530         GB-RDY-SPO/GBR/24/0019182  DR REDDYS
# 531         FR-MYLANLABS-2024M1115429      MYLAN
# 532             FR-KENVUE-20241207009     Kenvue
# 533         FR-MYLANLABS-2024M1116434      MYLAN
# 534         FR-MYLANLABS-2024M1116673      MYLAN
#
#                                                lit_ref   age age_cod age_grp  \
# 0    M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31.0      YR     nan
# 1    M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31.0      YR     nan
# 2    M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31.0      YR     nan
# 3    M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31.0      YR     nan
# 4    M^Kada H, Perazzo H, Munteanu M, Ngo Y, Ramanu...  31.0      YR     nan
# ..                                                 ...   ...     ...     ...
# 530                                                nan  14.0      YR       T
# 531                                                nan  81.0      YR     nan
# 532                                                nan  64.0     nan     nan
# 533                                                nan  58.0      YR     nan
# 534                                                nan  44.0      YR     nan
#
#      sex e_sub   wt wt_cod   rept_dt to_mfr occp_cod reporter_country  \
# 0      F     Y  nan    nan  20241004    nan       MD               FR
# 1      F     Y  nan    nan  20241004    nan       MD               FR
# 2      F     Y  nan    nan  20241004    nan       MD               FR
# 3      F     Y  nan    nan  20241004    nan       MD               FR
# 4      F     Y  nan    nan  20241004    nan       MD               FR
# ..   ...   ...  ...    ...       ...    ...      ...              ...
# 530    M     Y  nan    nan  20241230    nan       CN               GB
# 531    F     Y   52     KG  20241230    nan       MD               FR
# 532  nan     Y  nan    nan  20241231    nan       MD               FR
# 533    F     Y  nan    nan  20241231    nan       MD               FR
# 534    M     Y   75     KG  20241231    nan       MD               FR
#
#     occr_country primaryid_outc primaryid_rpsr rpsr_cod  \
# 0             FR     1454484512            nan      nan
# 1             FR     1454484512            nan      nan
# 2             FR     1454484512            nan      nan
# 3             FR     1454484512            nan      nan
# 4             FR     1454484512            nan      nan
# ..           ...            ...            ...      ...
# 530           GB      247893501            nan      nan
# 531           FR      247906781            nan      nan
# 532           FR      247919361            nan      nan
# 533           FR      247953721            nan      nan
# 534           FR      247953841            nan      nan
#
#           normalized_drugname
# 0                  CETIRIZINE
# 1                  CETIRIZINE
# 2                  CETIRIZINE
# 3                  CETIRIZINE
# 4                  CETIRIZINE
# ..                        ...
# 530              FEXOFENADINE
# 531                CETIRIZINE
# 532  CETIRIZINE HYDROCHLORIDE
# 533                CETIRIZINE
# 534                CETIRIZINE
#
# [535 rows x 52 columns]

# %%
new_df[new_df['dose_amt'].notna()][['dose_amt','dose_unit']]
# Out:
#      dose_amt dose_unit
# 32       10.0        MG
# 33       10.0        MG
# 34       10.0        MG
# 35       10.0        MG
# 38       10.0        MG
# ..        ...       ...
# 513      10.0        MG
# 514     120.0        MG
# 524      10.0        MG
# 525      10.0        MG
# 531      10.0        MG
#
# [313 rows x 2 columns]

# %%
new_df['dose_unit'].unique()
# Out:
# array(['nan', 'MG', 'GTT', 'ML'], dtype=object)

# %%
new_df.groupby('normalized_drugname')['dose_amt'].describe().sort_values(by='count', ascending=False).head(10)
# Out:
#                                                     count        mean  \
# normalized_drugname
# CETIRIZINE                                          130.0    9.923077
# CETIRIZINE HYDROCHLORIDE                             70.0   10.214286
# LORATADINE                                           33.0   28.484848
# DESLORATADINE                                        29.0    8.620690
# CHILDRENS CETIRIZINE HYDROCHLORIDE ALLERGY           27.0    5.796296
# FEXOFENADINE                                         18.0  176.666667
# FEXOFENADINE HYDROCHLORIDE                            4.0  180.000000
# LEVOCETIRIZINE                                        2.0    7.500000
# CETIRIZINE HYDROCHLORIDE\PSEUDOEPHEDRINE HYDROC...    0.0         NaN
# LEVOCETIRIZINE DIHYDROCHLORIDE                        0.0         NaN
#
#                                                           std    min     25%  \
# normalized_drugname
# CETIRIZINE                                           0.617765    5.0   10.00
# CETIRIZINE HYDROCHLORIDE                             1.792843    5.0   10.00
# LORATADINE                                          37.717802    5.0   10.00
# DESLORATADINE                                       10.847692    5.0    5.00
# CHILDRENS CETIRIZINE HYDROCHLORIDE ALLERGY           3.383385    2.5    5.00
# FEXOFENADINE                                        14.142136  120.0  180.00
# FEXOFENADINE HYDROCHLORIDE                           0.000000  180.0  180.00
# LEVOCETIRIZINE                                       3.535534    5.0    6.25
# CETIRIZINE HYDROCHLORIDE\PSEUDOEPHEDRINE HYDROC...        NaN    NaN     NaN
# LEVOCETIRIZINE DIHYDROCHLORIDE                            NaN    NaN     NaN
#
#                                                       50%     75%    max
# normalized_drugname
# CETIRIZINE                                           10.0   10.00   10.0
# CETIRIZINE HYDROCHLORIDE                             10.0   10.00   20.0
# LORATADINE                                           10.0   10.00  100.0
# DESLORATADINE                                         5.0    5.00   40.0
# CHILDRENS CETIRIZINE HYDROCHLORIDE ALLERGY            5.0    5.00   19.0
# FEXOFENADINE                                        180.0  180.00  180.0
# FEXOFENADINE HYDROCHLORIDE                          180.0  180.00  180.0
# LEVOCETIRIZINE                                        7.5    8.75   10.0
# CETIRIZINE HYDROCHLORIDE\PSEUDOEPHEDRINE HYDROC...    NaN     NaN    NaN
# LEVOCETIRIZINE DIHYDROCHLORIDE                        NaN     NaN    NaN

# %%
new_df[new_df['dose_amt'].isna()]['normalized_drugname'].value_counts().head()
# Out:
# normalized_drugname
# CETIRIZINE HYDROCHLORIDE                                  63
# CETIRIZINE                                                57
# LORATADINE                                                30
# FEXOFENADINE                                              22
# CETIRIZINE HYDROCHLORIDE\PSEUDOEPHEDRINE HYDROCHLORIDE    13
# Name: count, dtype: int64

# %%
def convert_dose_units(df):
    """
    Convert dose amounts to MG (milligrams) based on dose_unit.
    """
    df = df.copy()
    # leave MG as it is
    df.loc[df['dose_unit'] == 'MG', 'converted_dose_amt'] = df.loc[df['dose_unit'] == 'MG', 'dose_amt']
    # Convert ML to MG (assuming 1 ML = 1 MG for standardization)
    df.loc[df['dose_unit'] == 'ML', 'converted_dose_amt'] = df.loc[df['dose_unit'] == 'ML', 'dose_amt'] * 1
    
    # Convert GTT (drop conversion) to MG (assuming 1 GTT ≈ 0.05 MG)
    df.loc[df['dose_unit'] == 'GTT', 'converted_dose_amt'] = df.loc[df['dose_unit'] == 'GTT', 'dose_amt'] * 0.05
    
    # Convert dose_amt to float and drop remaining NaN values
    df['converted_dose_amt'] = pd.to_numeric(df['converted_dose_amt'], errors='coerce')
    
    return df

# Apply function
# new_df['converted_dose_amt'] = new_df['dose_amt'].apply(convert_dose_units)
dose_converted_df = convert_dose_units(new_df)

# %%
new_df['dose_unit'].unique()
# Out:
# array(['nan', 'MG', 'GTT', 'ML'], dtype=object)

# %%
new_df.groupby('normalized_drugname')['dose_amt'].describe().sort_values(by='count', ascending=False).head(10)
# Out:
#                                                     count        mean  \
# normalized_drugname
# CETIRIZINE                                          130.0    9.923077
# CETIRIZINE HYDROCHLORIDE                             70.0   10.214286
# LORATADINE                                           33.0   28.484848
# DESLORATADINE                                        29.0    8.620690
# CHILDRENS CETIRIZINE HYDROCHLORIDE ALLERGY           27.0    5.796296
# FEXOFENADINE                                         18.0  176.666667
# FEXOFENADINE HYDROCHLORIDE                            4.0  180.000000
# LEVOCETIRIZINE                                        2.0    7.500000
# CETIRIZINE HYDROCHLORIDE\PSEUDOEPHEDRINE HYDROC...    0.0         NaN
# LEVOCETIRIZINE DIHYDROCHLORIDE                        0.0         NaN
#
#                                                           std    min     25%  \
# normalized_drugname
# CETIRIZINE                                           0.617765    5.0   10.00
# CETIRIZINE HYDROCHLORIDE                             1.792843    5.0   10.00
# LORATADINE                                          37.717802    5.0   10.00
# DESLORATADINE                                       10.847692    5.0    5.00
# CHILDRENS CETIRIZINE HYDROCHLORIDE ALLERGY           3.383385    2.5    5.00
# FEXOFENADINE                                        14.142136  120.0  180.00
# FEXOFENADINE HYDROCHLORIDE                           0.000000  180.0  180.00
# LEVOCETIRIZINE                                       3.535534    5.0    6.25
# CETIRIZINE HYDROCHLORIDE\PSEUDOEPHEDRINE HYDROC...        NaN    NaN     NaN
# LEVOCETIRIZINE DIHYDROCHLORIDE                            NaN    NaN     NaN
#
#                                                       50%     75%    max
# normalized_drugname
# CETIRIZINE                                           10.0   10.00   10.0
# CETIRIZINE HYDROCHLORIDE                             10.0   10.00   20.0
# LORATADINE                                           10.0   10.00  100.0
# DESLORATADINE                                         5.0    5.00   40.0
# CHILDRENS CETIRIZINE HYDROCHLORIDE ALLERGY            5.0    5.00   19.0
# FEXOFENADINE                                        180.0  180.00  180.0
# FEXOFENADINE HYDROCHLORIDE                          180.0  180.00  180.0
# LEVOCETIRIZINE                                        7.5    8.75   10.0
# CETIRIZINE HYDROCHLORIDE\PSEUDOEPHEDRINE HYDROC...    NaN     NaN    NaN
# LEVOCETIRIZINE DIHYDROCHLORIDE                        NaN     NaN    NaN

# %%
new_df.groupby('normalized_drugname')['dose_amt'].describe().sort_values(by='count', ascending=False).head(10)
# Out:
#                                                     count        mean  \
# normalized_drugname
# CETIRIZINE                                          130.0    9.923077
# CETIRIZINE HYDROCHLORIDE                             70.0   10.214286
# LORATADINE                                           33.0   28.484848
# DESLORATADINE                                        29.0    8.620690
# CHILDRENS CETIRIZINE HYDROCHLORIDE ALLERGY           27.0    5.796296
# FEXOFENADINE                                         18.0  176.666667
# FEXOFENADINE HYDROCHLORIDE                            4.0  180.000000
# LEVOCETIRIZINE                                        2.0    7.500000
# CETIRIZINE HYDROCHLORIDE\PSEUDOEPHEDRINE HYDROC...    0.0         NaN
# LEVOCETIRIZINE DIHYDROCHLORIDE                        0.0         NaN
#
#                                                           std    min     25%  \
# normalized_drugname
# CETIRIZINE                                           0.617765    5.0   10.00
# CETIRIZINE HYDROCHLORIDE                             1.792843    5.0   10.00
# LORATADINE                                          37.717802    5.0   10.00
# DESLORATADINE                                       10.847692    5.0    5.00
# CHILDRENS CETIRIZINE HYDROCHLORIDE ALLERGY           3.383385    2.5    5.00
# FEXOFENADINE                                        14.142136  120.0  180.00
# FEXOFENADINE HYDROCHLORIDE                           0.000000  180.0  180.00
# LEVOCETIRIZINE                                       3.535534    5.0    6.25
# CETIRIZINE HYDROCHLORIDE\PSEUDOEPHEDRINE HYDROC...        NaN    NaN     NaN
# LEVOCETIRIZINE DIHYDROCHLORIDE                            NaN    NaN     NaN
#
#                                                       50%     75%    max
# normalized_drugname
# CETIRIZINE                                           10.0   10.00   10.0
# CETIRIZINE HYDROCHLORIDE                             10.0   10.00   20.0
# LORATADINE                                           10.0   10.00  100.0
# DESLORATADINE                                         5.0    5.00   40.0
# CHILDRENS CETIRIZINE HYDROCHLORIDE ALLERGY            5.0    5.00   19.0
# FEXOFENADINE                                        180.0  180.00  180.0
# FEXOFENADINE HYDROCHLORIDE                          180.0  180.00  180.0
# LEVOCETIRIZINE                                        7.5    8.75   10.0
# CETIRIZINE HYDROCHLORIDE\PSEUDOEPHEDRINE HYDROC...    NaN     NaN    NaN
# LEVOCETIRIZINE DIHYDROCHLORIDE                        NaN     NaN    NaN

# %%
new_df.groupby('normalized_drugname')['dose_amt'].describe()
# Out:
#                                                     count        mean  \
# normalized_drugname
# CETIRIZINE                                          130.0    9.923077
# CETIRIZINE HYDROCHLORIDE                             70.0   10.214286
# CETIRIZINE HYDROCHLORIDE\PSEUDOEPHEDRINE HYDROC...    0.0         NaN
# CHILDRENS CETIRIZINE HYDROCHLORIDE ALLERGY           27.0    5.796296
# DESLORATADINE                                        29.0    8.620690
# FEXOFENADINE                                         18.0  176.666667
# FEXOFENADINE HYDROCHLORIDE                            4.0  180.000000
# LEVOCETIRIZINE                                        2.0    7.500000
# LEVOCETIRIZINE DIHYDROCHLORIDE                        0.0         NaN
# LORATADINE                                           33.0   28.484848
# LORATADINE AND PSEUDOEPHEDRINE SULFATE                0.0         NaN
# LORATADINE\PSEUDOEPHEDRINE SULFATE                    0.0         NaN
#
#                                                           std    min     25%  \
# normalized_drugname
# CETIRIZINE                                           0.617765    5.0   10.00
# CETIRIZINE HYDROCHLORIDE                             1.792843    5.0   10.00
# CETIRIZINE HYDROCHLORIDE\PSEUDOEPHEDRINE HYDROC...        NaN    NaN     NaN
# CHILDRENS CETIRIZINE HYDROCHLORIDE ALLERGY           3.383385    2.5    5.00
# DESLORATADINE                                       10.847692    5.0    5.00
# FEXOFENADINE                                        14.142136  120.0  180.00
# FEXOFENADINE HYDROCHLORIDE                           0.000000  180.0  180.00
# LEVOCETIRIZINE                                       3.535534    5.0    6.25
# LEVOCETIRIZINE DIHYDROCHLORIDE                            NaN    NaN     NaN
# LORATADINE                                          37.717802    5.0   10.00
# LORATADINE AND PSEUDOEPHEDRINE SULFATE                    NaN    NaN     NaN
# LORATADINE\PSEUDOEPHEDRINE SULFATE                        NaN    NaN     NaN
#
#                                                       50%     75%    max
# normalized_drugname
# CETIRIZINE                                           10.0   10.00   10.0
# CETIRIZINE HYDROCHLORIDE                             10.0   10.00   20.0
# CETIRIZINE HYDROCHLORIDE\PSEUDOEPHEDRINE HYDROC...    NaN     NaN    NaN
# CHILDRENS CETIRIZINE HYDROCHLORIDE ALLERGY            5.0    5.00   19.0
# DESLORATADINE                                         5.0    5.00   40.0
# FEXOFENADINE                                        180.0  180.00  180.0
# FEXOFENADINE HYDROCHLORIDE                          180.0  180.00  180.0
# LEVOCETIRIZINE                                        7.5    8.75   10.0
# LEVOCETIRIZINE DIHYDROCHLORIDE                        NaN     NaN    NaN
# LORATADINE                                           10.0   10.00  100.0
# LORATADINE AND PSEUDOEPHEDRINE SULFATE                NaN     NaN    NaN
# LORATADINE\PSEUDOEPHEDRINE SULFATE                    NaN     NaN    NaN

# %%
median_dosage = new_df.groupby(['normalized_drugname', 'route'])['dose_amt'].median()
median_dosage
# Out:
# normalized_drugname                                     route
# CETIRIZINE                                              Oral                             10.0
#                                                         Transplacental                    NaN
#                                                         Unknown                          10.0
#                                                         nan                              10.0
# CETIRIZINE HYDROCHLORIDE                                Occlusive dressing technique     10.0
#                                                         Oral                             10.0
#                                                         Unknown                          10.0
# CETIRIZINE HYDROCHLORIDE\PSEUDOEPHEDRINE HYDROCHLORIDE  Oral                              NaN
# CHILDRENS CETIRIZINE HYDROCHLORIDE ALLERGY              Oral                              5.0
# DESLORATADINE                                           Oral                              5.0
#                                                         Unknown                           5.0
# FEXOFENADINE                                            Unknown                         120.0
#                                                         nan                             180.0
# FEXOFENADINE HYDROCHLORIDE                              Oral                            180.0
#                                                         Unknown                           NaN
# LEVOCETIRIZINE                                          Oral                              7.5
# LEVOCETIRIZINE DIHYDROCHLORIDE                          Oral                              NaN
# LORATADINE                                              Oral                             10.0
#                                                         Unknown                          10.0
#                                                         nan                              10.0
# LORATADINE AND PSEUDOEPHEDRINE SULFATE                  Unknown                           NaN
# LORATADINE\PSEUDOEPHEDRINE SULFATE                      Unknown                           NaN
#                                                         nan                               NaN
# Name: dose_amt, dtype: float64

# %%
new_df.columns
# Out:
# Index(['primaryid', 'caseid', 'drugname', 'event_dt', 'pt', 'outc_cod',
#        'drug_seq', 'role_cod', 'prod_ai', 'val_vbm', 'route', 'dose_vbm',
#        'cum_dose_chr', 'cum_dose_unit', 'dechal', 'rechal', 'lot_num',
#        'exp_dt', 'nda_num', 'dose_amt', 'dose_unit', 'dose_form', 'dose_freq',
#        'primaryid_reac', 'drug_rec_act', 'primaryid_demo', 'caseversion',
#        'i_f_code', 'mfr_dt', 'init_fda_dt', 'fda_dt', 'rept_cod', 'auth_num',
#        'mfr_num', 'mfr_sndr', 'lit_ref', 'age', 'age_cod', 'age_grp', 'sex',
#        'e_sub', 'wt', 'wt_cod', 'rept_dt', 'to_mfr', 'occp_cod',
#        'reporter_country', 'occr_country', 'primaryid_outc', 'primaryid_rpsr',
#        'rpsr_cod', 'normalized_drugname'],
#       dtype='object')

# %%
dose_converted_df[dose_converted_df['dose_unit'] =='GTT'][['dose_amt','converted_dose_amt','dose_unit']]
# Out:
#      dose_amt  converted_dose_amt dose_unit
# 141      10.0                 0.5       GTT
# 142      10.0                 0.5       GTT

# %%
dose_converted_df[dose_converted_df['dose_amt']][['pt','normalized_drugname']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 dose_converted_df[dose_converted_df['dose_amt']][['pt','normalized_drugname']]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index([ nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,  nan,\n       ...\n       10.0,  nan,  nan,  nan,  nan,  nan, 10.0,  nan,  nan,  nan],\n      dtype='float64', length=535)] are in the [columns]"

# %%
dose_converted_df['wt_cod'].unique()

# %%
def standardize_weight(df):
    df = df.copy()

    # Ensure weight column exists
    if 'wt' not in df.columns:
        raise ValueError("Column 'wt' not found in DataFrame")

    # Convert weight to float and handle NaN
    df = convert_str_to_float(df, 'wt')
    df = convert_nan_to_npnan(df, 'wt')

    # Create a new column 'converted_wt' in KG
    df['converted_wt'] = df['wt']

    # If any future dataset contains 'LB' (pounds), convert to kg
    if 'LB' in df['wt_cod'].dropna().unique():  # Drop NaN to avoid issues
        df.loc[df['wt_cod'] == 'LB', 'converted_wt'] *= 0.453592  # Convert lbs to kg

    return df

# %%
weight_converted_df = standardize_weight(dose_converted_df)

# %%
weight_converted_df[['wt', 'wt_cod', 'converted_wt']].dropna().sample(10)

# %%
weight_converted_df[['primaryid','caseid','drugname','normalized_drugname','event_dt','pt','outc_cod']]

# %%
def drop_irrelevant_columns(df):
    """
    Converts string 'nan' values to np.nan and drops unnecessary columns.
    """
    df = df.copy()
    
    # Convert all string 'nan' to np.nan
    for col in df.columns:
        df = convert_nan_to_npnan(df, col)

    columns_to_drop = [
        'val_vbm', 'lot_num', 'exp_dt', 'nda_num', 'auth_num', 'mfr_num', 
        'mfr_sndr', 'lit_ref', 'primaryid_reac', 'caseversion', 'to_mfr', 
        'occp_cod', 'reporter_country', 'occr_country', 'wt_cod'
    ]

    df = df.drop(columns=[col for col in columns_to_drop if col in df.columns], errors='ignore')
    return df

# %%
dropped_columns_df = drop_irrelevant_columns(weight_converted_df)

# %%
weight_converted_df[weight_converted_df['dose_unit'].isna()]

# %%
from sklearn.preprocessing import LabelEncoder

def encode_categorical_variables(df):
    """
    Converts string 'nan' to np.nan and encodes categorical variables.
    """
    df = df.copy()

    # Convert NaN values in categorical columns
    categorical_cols = ['i_f_code', 'rechal', 'dechal', 'drug_rec_act', 'route', 'dose_form', 'dose_freq']
    for col in categorical_cols:
        if col in df.columns:
            df = convert_nan_to_npnan(df, col)

    # Binary conversion (Foreign vs. US)
    if 'i_f_code' in df.columns:
        df['i_f_code'] = df['i_f_code'].map({'Y': 1, 'N': 0})

    # Ordinal Encoding
    ordinal_cols = ['rechal', 'dechal', 'drug_rec_act']
    for col in ordinal_cols:
        if col in df.columns:
            df[col] = LabelEncoder().fit_transform(df[col].astype(str))

    # One-Hot Encoding for Nominal Categorical Variables
    df = pd.get_dummies(df, columns=['route', 'dose_form', 'dose_freq'], drop_first=True)

    return df

# %%
encoded_df = encode_categorical_variables(dropped_columns_df)

# %%
def convert_date_columns(df):
    """
    Converts string 'nan' to np.nan and converts date columns to datetime format.
    """
    df = df.copy()
    
    # Convert NaN values in date columns
    date_cols = ['event_dt', 'mfr_dt', 'init_fda_dt', 'fda_dt', 'rept_dt']
    for col in date_cols:
        if col in df.columns:
            df = convert_nan_to_npnan(df, col)

    # Convert to datetime format
    for col in date_cols:
        if col in df.columns:
            df[col] = pd.to_datetime(df[col], format='%Y%m%d', errors='coerce')

    return df

# %%
date_converted_df = convert_date_columns(encoded_df)

# %%
date_converted_df.info()
date_converted_df.head()

# %%
date_converted_df.groupby('normalized_drugname')['dose_amt'].value_counts()

# %%
date_converted_df[date_converted_df['dose_amt'].isna()]['normalized_drugname'].value_counts()

# %%
def further_normalize_drug_names(df, column='normalized_drugname'):
    """
    Further normalizes drug names by handling variations in formatting, 
    synonyms, and redundant terms.
    """
    df = df.copy()
    
    # Convert different separators to a uniform format
    df[column] = df[column].str.replace(r'\\', ' / ', regex=True)  # Fixes backslashes
    df[column] = df[column].str.replace(r' AND ', ' / ', regex=True)
    
    # Standardize known variations
    drug_mapping = {
        "CETIRIZINE HYDROCHLORIDE": "CETIRIZINE",
        "FEXOFENADINE HYDROCHLORIDE": "FEXOFENADINE",
        r"LORATADINE\PSEUDOEPHEDRINE SULFATE": "LORATADINE / PSEUDOEPHEDRINE SULFATE",  # Use raw string (r"")
        r"CETIRIZINE HYDROCHLORIDE\PSEUDOEPHEDRINE HYDROCHLORIDE": "CETIRIZINE / PSEUDOEPHEDRINE"
    }
    
    # Apply mapping
    df[column] = df[column].replace(drug_mapping)
    
    return df

# Apply function
final_normalized_df = further_normalize_drug_names(date_converted_df)

# %%
date_converted_df['normalized_drugname'].unique()

# %%
print(final_normalized_df['normalized_drugname'].unique())

# %%
import re

def further_normalize_drug_names(df, column='normalized_drugname'):
    """
    Further normalizes drug names by handling variations in formatting, 
    synonyms, and redundant terms.
    """
    df = df.copy()

    # Standardize separators (replace any backslashes or multiple spaces)
    df[column] = df[column].str.replace(r'[\\]', ' / ', regex=True)
    df[column] = df[column].str.replace(r'\s+', ' ', regex=True).str.strip()  # Remove extra spaces

    # Define a mapping dictionary for common variations
    drug_mapping = {
        "CETIRIZINE HYDROCHLORIDE": "CETIRIZINE",
        "FEXOFENADINE HYDROCHLORIDE": "FEXOFENADINE",
        "LEVOCETIRIZINE DIHYDROCHLORIDE": "LEVOCETIRIZINE",
        # "CHILDRENS CETIRIZINE HYDROCHLORIDE ALLERGY": "CETIRIZINE",
        "CETIRIZINE HYDROCHLORIDE PSEUDOEPHEDRINE HYDROCHLORIDE": "CETIRIZINE / PSEUDOEPHEDRINE",
        "LORATADINE PSEUDOEPHEDRINE SULFATE": "LORATADINE / PSEUDOEPHEDRINE",
        "LORATADINE AND PSEUDOEPHEDRINE SULFATE": "LORATADINE / PSEUDOEPHEDRINE",
        r"LORATADINE / PSEUDOEPHEDRINE SULFATE": "LORATADINE / PSEUDOEPHEDRINE",
        r"CETIRIZINE HYDROCHLORIDE / PSEUDOEPHEDRINE HYDROCHLORIDE": "CETIRIZINE / PSEUDOEPHEDRINE",
    }

    # Apply mapping
    df[column] = df[column].replace(drug_mapping)

    return df

# Apply function
final_normalized_df = further_normalize_drug_names(date_converted_df)

# Check results
print(final_normalized_df['normalized_drugname'].unique())

# %%
import re

def final_normalize_drug_names(df, column='normalized_drugname'):
    """
    Further normalizes drug names by handling variations in formatting, 
    synonyms, and redundant terms.
    """
    df = df.copy()

    # Standardize separators (replace any backslashes or multiple spaces)
    df[column] = df[column].str.replace(r'[\\]', ' / ', regex=True)
    df[column] = df[column].str.replace(r'\s+', ' ', regex=True).str.strip()  # Remove extra spaces

    # Define a mapping dictionary for common variations
    drug_mapping = {
        "CETIRIZINE HYDROCHLORIDE": "CETIRIZINE",
        "FEXOFENADINE HYDROCHLORIDE": "FEXOFENADINE",
        "LEVOCETIRIZINE DIHYDROCHLORIDE": "LEVOCETIRIZINE",
        # "CHILDRENS CETIRIZINE HYDROCHLORIDE ALLERGY": "CETIRIZINE",
        "CETIRIZINE HYDROCHLORIDE PSEUDOEPHEDRINE HYDROCHLORIDE": "CETIRIZINE / PSEUDOEPHEDRINE",
        "LORATADINE PSEUDOEPHEDRINE SULFATE": "LORATADINE / PSEUDOEPHEDRINE",
        "LORATADINE AND PSEUDOEPHEDRINE SULFATE": "LORATADINE / PSEUDOEPHEDRINE",
        r"LORATADINE / PSEUDOEPHEDRINE SULFATE": "LORATADINE / PSEUDOEPHEDRINE",
        r"CETIRIZINE HYDROCHLORIDE / PSEUDOEPHEDRINE HYDROCHLORIDE": "CETIRIZINE / PSEUDOEPHEDRINE",
    }

    # Apply mapping
    df[column] = df[column].replace(drug_mapping)

    return df
final_df = final_normalize_drug_names(date_converted_df)

# %%
final_df['normalized_drugname'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 final_df['normalized_drugname'].unique()
#
# NameError: name 'final_df' is not defined

# %%
final_df[['drugnmae','normalized_drugname','prod_ai']].head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[229], line 1
# ----> 1 final_df[['drugnmae','normalized_drugname','prod_ai']].head()
#
# NameError: name 'final_df' is not defined
